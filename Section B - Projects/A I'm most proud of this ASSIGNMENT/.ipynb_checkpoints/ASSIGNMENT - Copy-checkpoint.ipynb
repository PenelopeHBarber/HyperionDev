# %%
#laura
#check pd.isnull
#list of types
#for loop and type
#print(df.type)

# %%
###################################################################################################

# %%
#Environment:
#pip install Notebook
#Python 3 Jupyter Notebook 
#Windows 10

# %%
#import packages
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import OrdinalEncoder

# %%
#acronyms used to save typeing time:
#Health Faciltiy Assessment = hfa
#Master Health Facility = mhf

# %%
#file path for files
#NB: ASSESSOR NEEDS TO SPECIFY THEIR OWN FILE PATH

hfa_file_path = r'C:\\Users\\Penelope\\Documents\\ASSIGNMENT\\Health Facility Assessment.xlsx'
mhf_file_path = r'C:\\Users\\Penelope\\Documents\\ASSIGNMENT\\Master Health Facility.xlsx'

# %%
#read files

hfa = pd.read_excel (hfa_file_path)
mhf = pd.read_excel (mhf_file_path)

# %%
#check it imported correctly
hfa.head(6)
# Out:
#    Unnamed: 0  number form.health_centre_information.facility_name  \
# 0           0       0                             William hospital
# 1           1       1                         Kathryn Hospital/CHC
# 2           2       2                             Jessica Hospital
# 3           3       3                                   Lauren CHC
# 4           4       4                                    Tammy CHC
# 5           5       5                                          ---
#
#          form.facility_gps  \
# 0    60.234598, -90.157892
# 1  21.2454855, -107.509120
# 2     -0.178657, -9.190029
# 3    35.856989, -87.512790
# 4   54.7148835, 150.744813
# 5    22.8567535, 19.262410
#
#   form.health_centre_information.location_information.region_province  \
# 0                                           Southern
# 1                                           Southern
# 2                                           Southern
# 3                                           Southern
# 4                                           Southern
# 5                                                ---
#
#   form.health_centre_information.location_information.district  \
# 0                                            Pujehun
# 1                                                 Bo
# 2                                                 Bo
# 3                                             Bonthe
# 4                                             Bonthe
# 5                                                ---
#
#   form.health_centre_information.location_information.chiefdom  \
# 0                                           New York
# 1                                            Arizona
# 2                                         New Mexico
# 3                                           Missouri
# 4                                           Virginia
# 5                                                ---
#
#   form.health_centre_information.location_information.facility_location  \
# 0                                          Jasonfort
# 1                                    West Jamesshire
# 2                                        Robertsside
# 3                                   Port Christopher
# 4                                           Reneeton
# 5                                                ---
#
#   form.health_centre_information.facility_type  \
# 0                        community_health_post
# 1                        community_health_post
# 2                        community_health_post
# 3                                     mch_post
# 4                        community_health_post
# 5                                          ---
#
#   form.health_centre_information.facility_type_other  ...  \
# 0                                                ---  ...
# 1                                                ---  ...
# 2                                                ---  ...
# 3                                                ---  ...
# 4                                                ---  ...
# 5                                                ---  ...
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                  4
# 1                                                1.5
# 2                                                  2
# 3                                                  4
# 4                                                  4
# 5                                                  0
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  3
# 5                                                  0
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#   form.grp_infection_prevention_and_control.score_infection_prevention_and_control  \
# 0                                               10.5
# 1                                                5.5
# 2                                                 10
# 3                                                 12
# 4                                                 12
# 5                                                  0
#
#   form.grp_infection_prevention_and_control.score_max_infection_prevention_and_control  \
# 0                                                 27
# 1                                                 27
# 2                                                 27
# 3                                                 27
# 4                                                 27
# 5                                                 27
#
#   form.question1.score_logistics_patient_and_sample_transfer  \
# 0                                               19.5
# 1                                                 21
# 2                                               33.5
# 3                                               34.5
# 4                                               29.5
# 5                                                ---
#
#   form.question1.score_max_logistics_patient_and_sample_transfer  \
# 0                                                 44
# 1                                                 44
# 2                                                 44
# 3                                                 44
# 4                                                 44
# 5                                                ---
#
#   form.score_total form.score_max_total
# 0             48.5                102.0
# 1             35.5                102.0
# 2             55.5                102.0
# 3             57.5                102.0
# 4             55.0                102.0
# 5              NaN                  NaN
#
# [6 rows x 205 columns]

# %%
#check it imported correctly
mhf.head()
# Out:
#    Unnamed: 0  1  Southern  Bo district     Badjia             Ngelehun CHC  \
# 0           0  2  Southern  Bo district    Florida             Victoria CHP
# 1           1  3  Southern  Bo district  Louisiana             Kristina CHC
# 2           2  4  Southern  Bo district  Louisiana  James Regional Hospital
# 3           3  5  Southern  Bo district  Louisiana   Jake Regional Hospital
# 4           4  6  Southern  Bo district  Louisiana               Donna MCHP
#
#     CHC  MoHS  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0  MCHP  MoHS         NaN         NaN         NaN
# 1   CHC  MoHS         NaN         NaN         NaN
# 2  MCHP  MoHS         NaN         NaN         NaN
# 3  MCHP  MoHS         NaN         NaN         NaN
# 4  MCHP  MoHS         NaN         NaN         NaN

# %%
#check column types
hfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 205 entries, Unnamed: 0 to form.score_max_total
# dtypes: float64(2), int64(2), object(201)
# memory usage: 232.4+ KB

# %%
#from inspection there are more than 2 columns with numerical data, but they are showing as object

# %%
#LIST OF COLUMNS
cols = hfa.columns.to_list()
len(cols)
# Out:
# 205

# %%
#REPLACE "---" WITH "" FOR NUMERICAL LIST

#convert all columns to str
for col in cols:
    hfa[col] = hfa[col].astype('str')

# %%
hfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 205 entries, Unnamed: 0 to form.score_max_total
# dtypes: object(205)
# memory usage: 232.4+ KB

# %%
for col in cols:
    hfa[col] = hfa[col].str.replace("---","")

# %%
hfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 205 entries, Unnamed: 0 to form.score_max_total
# dtypes: object(205)
# memory usage: 232.4+ KB

# %%
for col in cols:
    #hfa[col] = pd.to_numeric(hfa[col], errors='ignore')
    try:
        hfa[col] = hfa[col].astype(float)
    except:
        print(hfa[col])
# Out:
# 0              William hospital
# 1          Kathryn Hospital/CHC
# 2              Jessica Hospital
# 3                    Lauren CHC
# 4                     Tammy CHC
#                  ...
# 140    Nicole Tertiary Hospital
# 141             Nicole hospital
# 142                  Latoya CHC
# 143                  Amanda CHC
# 144              Cindy Hospital
# Name: form.health_centre_information.facility_name, Length: 145, dtype: object
# 0         60.234598, -90.157892
# 1       21.2454855, -107.509120
# 2          -0.178657, -9.190029
# 3         35.856989, -87.512790
# 4        54.7148835, 150.744813
#                  ...
# 140       63.155728, -82.989076
# 141    -56.2934725, -143.818347
# 142      -18.108589, 157.038699
# 143        2.369627, 179.543785
# 144      73.6720145, 178.295107
# Name: form.facility_gps, Length: 145, dtype: object
# 0      Southern
# 1      Southern
# 2      Southern
# 3      Southern
# 4      Southern
#          ...
# 140    Southern
# 141    Southern
# 142    Northern
# 143     Eastern
# 144    Northern
# Name: form.health_centre_information.location_information.region_province, Length: 145, dtype: object
# 0        Pujehun
# 1             Bo
# 2             Bo
# 3         Bonthe
# 4         Bonthe
#          ...
# 140           Bo
# 141           Bo
# 142    Tonkolili
# 143     Kailahun
# 144    Tonkolili
# Name: form.health_centre_information.location_information.district, Length: 145, dtype: object
# 0           New York
# 1            Arizona
# 2         New Mexico
# 3           Missouri
# 4           Virginia
#            ...
# 140     Rhode Island
# 141         Virginia
# 142    Massachusetts
# 143         Missouri
# 144          Georgia
# Name: form.health_centre_information.location_information.chiefdom, Length: 145, dtype: object
# 0             Jasonfort
# 1       West Jamesshire
# 2           Robertsside
# 3      Port Christopher
# 4              Reneeton
#              ...
# 140       New Christine
# 141        Stevechester
# 142         East Marcus
# 143       Williamsmouth
# 144       Hooverchester
# Name: form.health_centre_information.location_information.facility_location, Length: 145, dtype: object
# 0        community_health_post
# 1        community_health_post
# 2        community_health_post
# 3                     mch_post
# 4        community_health_post
#                 ...
# 140    community_health_centre
# 141      community_health_post
# 142    community_health_centre
# 143      community_health_post
# 144                   mch_post
# Name: form.health_centre_information.facility_type, Length: 145, dtype: object
# 0
# 1
# 2
# 3
# 4
#       ..
# 140
# 141
# 142
# 143
# 144
# Name: form.health_centre_information.facility_type_other, Length: 145, dtype: object
# 0      government_public
# 1      government_public
# 2      government_public
# 3      government_public
# 4      government_public
#              ...
# 140    government_public
# 141    government_public
# 142    government_public
# 143    government_public
# 144    government_public
# Name: form.health_centre_information.managing_authority, Length: 145, dtype: object
# 0
# 1
# 2
# 3
# 4
#       ..
# 140
# 141
# 142
# 143
# 144
# Name: form.health_centre_information.managing_authority_other, Length: 145, dtype: object
# 0      peri_urban
# 1           rural
# 2           rural
# 3      peri_urban
# 4      peri_urban
#           ...
# 140         rural
# 141         rural
# 142    peri_urban
# 143    peri_urban
# 144    peri_urban
# Name: form.health_centre_information.setting, Length: 145, dtype: object
# 0      yes
# 1      yes
# 2      yes
# 3       no
# 4       no
#       ...
# 140    yes
# 141    yes
# 142     no
# 143    yes
# 144     no
# Name: form.health_centre_information.outpatient_only, Length: 145, dtype: object
# 0      1
# 1      1
# 2      2
# 3      1
# 4      3
#       ..
# 140    1
# 141    3
# 142    5
# 143    1
# 144    1
# Name: form.health_centre_information.capacity.number_consultation_rooms, Length: 145, dtype: object
# 0      0
# 1      1
# 2      1
# 3      2
# 4      1
#       ..
# 140    1
# 141    3
# 142    3
# 143    0
# 144    1
# Name: form.health_centre_information.capacity.number_inpatient_beds, Length: 145, dtype: object
# 0      1
# 1      2
# 2      1
# 3      3
# 4      1
#       ..
# 140    1
# 141    1
# 142    2
# 143    4
# 144    1
# Name: form.health_centre_information.capacity.number_maternity_beds, Length: 145, dtype: object
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 140    1
# 141    0
# 142    2
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_health_officer.cho_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    1
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_health_officer.cho_number_present_at_visit, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_health_technician.cht_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_health_technician.cht_number_present_at_visit, Length: 145, dtype: object
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    5
# Name: form.health_centre_information.group_number_employed.list_community_health_assistant.cha_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_health_assistant.cha_number_present_at_visit, Length: 145, dtype: object
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    1
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_midwives.cm_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    1
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_community_midwives.cm_number_present_at_visit, Length: 145, dtype: object
# 0      0
# 1      2
# 2      2
# 3      0
# 4      3
#       ..
# 140    1
# 141    2
# 142    6
# 143    1
# 144    0
# Name: form.health_centre_information.group_number_employed.list_sechn.sechn_number_in_post, Length: 145, dtype: object
# 0      0
# 1      2
# 2      0
# 3      0
# 4      2
#       ..
# 140    1
# 141    0
# 142    6
# 143    1
# 144    0
# Name: form.health_centre_information.group_number_employed.list_sechn.sechn_number_present_at_visit, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_laboratory_technicians.lab_tech_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_laboratory_technicians.lab_tech_number_present_at_visit, Length: 145, dtype: object
# 0      2
# 1      2
# 2      2
# 3      3
# 4      1
#       ..
# 140    2
# 141    2
# 142    1
# 143    2
# 144    3
# Name: form.health_centre_information.group_number_employed.list_mch_aides.mch_aides_number_in_post, Length: 145, dtype: object
# 0      1
# 1      2
# 2      2
# 3      3
# 4      1
#       ..
# 140    1
# 141    1
# 142    1
# 143    2
# 144    3
# Name: form.health_centre_information.group_number_employed.list_mch_aides.mch_aides_number_present_at_visit, Length: 145, dtype: object
# 0      1
# 1      0
# 2      2
# 3      0
# 4      1
#       ..
# 140    1
# 141    1
# 142    1
# 143    0
# 144    1
# Name: form.health_centre_information.group_number_employed.list_cleaner_porter.cleaner_porter_number_in_post, Length: 145, dtype: object
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 140    1
# 141    0
# 142    1
# 143    0
# 144    1
# Name: form.health_centre_information.group_number_employed.list_cleaner_porter.cleaner_porter_number_present_at_visit, Length: 145, dtype: object
# 0       4
# 1      13
# 2      18
# 3       0
# 4       0
#        ..
# 140     0
# 141     0
# 142     1
# 143     0
# 144     0
# Name: form.health_centre_information.group_number_employed.list_other.other_number_in_post, Length: 145, dtype: object
# 0      0
# 1      5
# 2      3
# 3      0
# 4      0
#       ..
# 140    0
# 141    0
# 142    1
# 143    0
# 144    0
# Name: form.health_centre_information.group_number_employed.list_other.other_number_present_at_visit, Length: 145, dtype: object
# 0                       TBA
# 1                      CHWs
# 2                      CHWs
# 3
# 4
#                ...
# 140
# 141
# 142    Laboratory Assistant
# 143
# 144
# Name: form.health_centre_information.group_number_employed.list_other.other_staff_cadre, Length: 145, dtype: object
# 0      consultations hr information_education_communi...
# 1      consultations hr information_education_communi...
# 2      consultations hr information_education_communi...
# 3      consultations hr information_education_communi...
# 4      consultations hr information_education_communi...
#                              ...
# 140    consultations hr information_education_communi...
# 141    consultations hr information_education_communi...
# 142    consultations hr information_education_communi...
# 143    consultations hr information_education_communi...
# 144    consultations hr information_education_communi...
# Name: form.sections_to_review, Length: 145, dtype: object
# 0      221
# 1      270
# 2      748
# 3       79
# 4      928
#       ...
# 140    661
# 141    524
# 142    463
# 143    399
# 144    180
# Name: form.consultations.head_count.month_1, Length: 145, dtype: object
# 0      225
# 1      238
# 2      604
# 3       93
# 4      900
#       ...
# 140    367
# 141    422
# 142    325
# 143    361
# 144    298
# Name: form.consultations.head_count.month_2, Length: 145, dtype: object
# 0      304
# 1      245
# 2      405
# 3      101
# 4      467
#       ...
# 140    641
# 141    333
# 142    510
# 143    412
# 144    380
# Name: form.consultations.head_count.month_3, Length: 145, dtype: object
# 0      217
# 1      269
# 2      576
# 3       21
# 4      177
#       ...
# 140    509
# 141    457
# 142    496
# 143    365
# 144    115
# Name: form.consultations.head_count.month_4, Length: 145, dtype: object
# 0      144
# 1      178
# 2      466
# 3      144
# 4      165
#       ...
# 140    327
# 141    366
# 142    707
# 143     56
# 144    309
# Name: form.consultations.general_outpatient.month_1, Length: 145, dtype: object
# 0      151
# 1      155
# 2      474
# 3       88
# 4      399
#       ...
# 140    263
# 141    374
# 142    298
# 143     54
# 144    245
# Name: form.consultations.general_outpatient.month_2, Length: 145, dtype: object
# 0      158
# 1      171
# 2      338
# 3      101
# 4      408
#       ...
# 140    286
# 141    357
# 142    317
# 143     54
# 144    196
# Name: form.consultations.general_outpatient.month_3, Length: 145, dtype: object
# 0      145
# 1      182
# 2      418
# 3      121
# 4      198
#       ...
# 140    291
# 141    239
# 142    291
# 143     40
# 144    310
# Name: form.consultations.general_outpatient.month_4, Length: 145, dtype: object
# 0      19
# 1      15
# 2       9
# 3       7
# 4       4
#        ..
# 140    18
# 141    12
# 142    19
# 143    16
# 144     4
# Name: form.consultations.deliveries.month_1, Length: 145, dtype: object
# 0      20
# 1      15
# 2      13
# 3       5
# 4       5
#        ..
# 140    17
# 141    13
# 142    11
# 143    14
# 144     7
# Name: form.consultations.deliveries.month_2, Length: 145, dtype: object
# 0      21
# 1      17
# 2       7
# 3      11
# 4       4
#        ..
# 140    18
# 141    15
# 142    14
# 143    17
# 144     3
# Name: form.consultations.deliveries.month_3, Length: 145, dtype: object
# 0      18
# 1      16
# 2       7
# 3       3
# 4       5
#        ..
# 140    17
# 141    13
# 142    20
# 143    15
# 144     8
# Name: form.consultations.deliveries.month_4, Length: 145, dtype: object
# 0      12
# 1      18
# 2      18
# 3       5
# 4       3
#        ..
# 140    18
# 141    14
# 142    28
# 143    13
# 144    11
# Name: form.consultations.pent_vaccines.month_1, Length: 145, dtype: object
# 0      10
# 1      16
# 2      22
# 3       5
# 4       5
#        ..
# 140    16
# 141    13
# 142    26
# 143    16
# 144     9
# Name: form.consultations.pent_vaccines.month_2, Length: 145, dtype: object
# 0      18
# 1      19
# 2      24
# 3       6
# 4       4
#        ..
# 140    24
# 141    13
# 142    18
# 143    17
# 144    12
# Name: form.consultations.pent_vaccines.month_3, Length: 145, dtype: object
# 0      20
# 1      16
# 2      15
# 3       7
# 4       1
#        ..
# 140    21
# 141    13
# 142    12
# 143    19
# 144    13
# Name: form.consultations.pent_vaccines.month_4, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_human_resources.choice_labels, Length: 145, dtype: object
# 0            not_completed
# 1            not_completed
# 2            not_completed
# 3            not_completed
# 4            not_completed
#               ...
# 140          not_completed
# 141    partially_completed
# 142              completed
# 143          not_completed
# 144    partially_completed
# Name: form.ql_human_resources.hr_focal_point, Length: 145, dtype: object
# 0                completed
# 1      partially_completed
# 2                completed
# 3      partially_completed
# 4                completed
#               ...
# 140    partially_completed
# 141              completed
# 142              completed
# 143    partially_completed
# 144              completed
# Name: form.ql_human_resources.hr_staff_received_info, Length: 145, dtype: object
# 0            not_completed
# 1            not_completed
# 2      partially_completed
# 3      partially_completed
# 4            not_completed
#               ...
# 140    partially_completed
# 141          not_completed
# 142              completed
# 143          not_completed
# 144              completed
# Name: form.ql_human_resources.hr_healthcare_provider_training, Length: 145, dtype: object
# 0            not_completed
# 1            not_completed
# 2      partially_completed
# 3            not_completed
# 4      partially_completed
#               ...
# 140    partially_completed
# 141          not_completed
# 142              completed
# 143          not_completed
# 144              completed
# Name: form.ql_human_resources.hr_healthcare_provider_revised_training, Length: 145, dtype: object
# 0                completed
# 1                completed
# 2                completed
# 3            not_completed
# 4                completed
#               ...
# 140    partially_completed
# 141          not_completed
# 142              completed
# 143          not_completed
# 144              completed
# Name: form.ql_human_resources.hr_daily_staff_list, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_information_education_communication.choice_labels, Length: 145, dtype: object
# 0      not_displayed
# 1      not_displayed
# 2          displayed
# 3          displayed
# 4      not_displayed
#            ...
# 140        displayed
# 141    not_displayed
# 142        displayed
# 143        displayed
# 144        displayed
# Name: form.ql_information_education_communication.iec_handwashing_procedure, Length: 145, dtype: object
# 0          displayed
# 1          displayed
# 2      not_displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140        displayed
# 141    not_displayed
# 142    not_displayed
# 143    not_displayed
# 144        displayed
# Name: form.ql_information_education_communication.iec_physical_distancing, Length: 145, dtype: object
# 0          displayed
# 1          displayed
# 2          displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140    not_displayed
# 141    not_displayed
# 142        displayed
# 143    not_displayed
# 144    not_displayed
# Name: form.ql_information_education_communication.iec_covering_nose_mouth, Length: 145, dtype: object
# 0          displayed
# 1      not_displayed
# 2      not_displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140    not_displayed
# 141    not_displayed
# 142        displayed
# 143        displayed
# 144    not_displayed
# Name: form.ql_information_education_communication.iec_early_symptom_recognition, Length: 145, dtype: object
# 0          displayed
# 1      not_displayed
# 2      not_displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140    not_displayed
# 141    not_displayed
# 142        displayed
# 143        displayed
# 144        displayed
# Name: form.ql_information_education_communication.iec_when_facility_vs_home, Length: 145, dtype: object
# 0          displayed
# 1      not_displayed
# 2          displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140        displayed
# 141    not_displayed
# 142    not_displayed
# 143        displayed
# 144        displayed
# Name: form.ql_information_education_communication.iec_rational_ppe_use, Length: 145, dtype: object
# 0          displayed
# 1          displayed
# 2          displayed
# 3      not_displayed
# 4      not_displayed
#            ...
# 140        displayed
# 141        displayed
# 142        displayed
# 143        displayed
# 144        displayed
# Name: form.ql_information_education_communication.iec_helpline_number, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_surveillance.choice_labels, Length: 145, dtype: object
# 0          fully_operational
# 1      partially_operational
# 2      partially_operational
# 3          fully_operational
# 4          fully_operational
#                ...
# 140             not_in_place
# 141             not_in_place
# 142        fully_operational
# 143        fully_operational
# 144    partially_operational
# Name: form.ql_surveillance.surv_procedure_for_notification, Length: 145, dtype: object
# 0          fully_operational
# 1               not_in_place
# 2               not_in_place
# 3               not_in_place
# 4               not_in_place
#                ...
# 140             not_in_place
# 141             not_in_place
# 142             not_in_place
# 143             not_in_place
# 144    partially_operational
# Name: form.ql_surveillance.surv_official_case_definition, Length: 145, dtype: object
# 0          fully_operational
# 1          fully_operational
# 2          fully_operational
# 3          fully_operational
# 4          fully_operational
#                ...
# 140        fully_operational
# 141        fully_operational
# 142    partially_operational
# 143        fully_operational
# 144        fully_operational
# Name: form.ql_surveillance.surv_hotline_number, Length: 145, dtype: object
# 0          fully_operational
# 1          fully_operational
# 2          fully_operational
# 3          fully_operational
# 4          fully_operational
#                ...
# 140        fully_operational
# 141        fully_operational
# 142        fully_operational
# 143    partially_operational
# 144        fully_operational
# Name: form.ql_surveillance.surv_timely_data_reported_to_district, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_triage_and_early_recognition.choice_labels, Length: 145, dtype: object
# 0          fully_operational
# 1               not_in_place
# 2               not_in_place
# 3               not_in_place
# 4               not_in_place
#                ...
# 140        fully_operational
# 141             not_in_place
# 142    partially_operational
# 143             not_in_place
# 144        fully_operational
# Name: form.ql_triage_and_early_recognition.ter_screening_area_set_up, Length: 145, dtype: object
# 0               not_in_place
# 1               not_in_place
# 2               not_in_place
# 3               not_in_place
# 4               not_in_place
#                ...
# 140    partially_operational
# 141             not_in_place
# 142        fully_operational
# 143             not_in_place
# 144        fully_operational
# Name: form.ql_triage_and_early_recognition.ter_symptom_screening_questionnaires, Length: 145, dtype: object
# 0      fully_operational
# 1           not_in_place
# 2           not_in_place
# 3      fully_operational
# 4           not_in_place
#              ...
# 140    fully_operational
# 141         not_in_place
# 142    fully_operational
# 143         not_in_place
# 144    fully_operational
# Name: form.ql_triage_and_early_recognition.ter_temperature_measurement_at_triage, Length: 145, dtype: object
# 0          fully_operational
# 1      partially_operational
# 2      partially_operational
# 3          fully_operational
# 4          fully_operational
#                ...
# 140    partially_operational
# 141             not_in_place
# 142        fully_operational
# 143        fully_operational
# 144        fully_operational
# Name: form.ql_triage_and_early_recognition.ter_physical_distancing_in_waiting, Length: 145, dtype: object
# 0               not_in_place
# 1               not_in_place
# 2               not_in_place
# 3               not_in_place
# 4          fully_operational
#                ...
# 140             not_in_place
# 141             not_in_place
# 142    partially_operational
# 143             not_in_place
# 144             not_in_place
# Name: form.ql_triage_and_early_recognition.ter_separate_waiting_for_symptomatic, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_chw.choice_labels, Length: 145, dtype: object
# 0      not_in_place
# 1      not_in_place
# 2      not_in_place
# 3           partial
# 4           partial
#            ...
# 140        adequate
# 141    not_in_place
# 142         partial
# 143         partial
# 144         partial
# Name: form.ql_chw.chw_trained_precautions, Length: 145, dtype: object
# 0      not_in_place
# 1      not_in_place
# 2      not_in_place
# 3           partial
# 4           partial
#            ...
# 140        adequate
# 141    not_in_place
# 142        adequate
# 143        adequate
# 144         partial
# Name: form.ql_chw.chw_trained_community_service, Length: 145, dtype: object
# 0           partial
# 1           partial
# 2               nan
# 3           partial
# 4          adequate
#            ...
# 140         partial
# 141    not_in_place
# 142        adequate
# 143    not_in_place
# 144         partial
# Name: form.ql_chw.chw_drugs, Length: 145, dtype: object
# 0          adequate
# 1      not_in_place
# 2           partial
# 3           partial
# 4      not_in_place
#            ...
# 140         partial
# 141    not_in_place
# 142         partial
# 143    not_in_place
# 144        adequate
# Name: form.ql_chw.chw_gloves, Length: 145, dtype: object
# 0      not_in_place
# 1           partial
# 2           partial
# 3           partial
# 4          adequate
#            ...
# 140    not_in_place
# 141    not_in_place
# 142         partial
# 143    not_in_place
# 144        adequate
# Name: form.ql_chw.chw_masks, Length: 145, dtype: object
# 0      not_in_place
# 1      not_in_place
# 2      not_in_place
# 3      not_in_place
# 4           partial
#            ...
# 140         partial
# 141    not_in_place
# 142         partial
# 143             nan
# 144         partial
# Name: form.ql_chw.chw_iec_materials, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_isolation_physical_distancing.choice_labels, Length: 145, dtype: object
# 0               not_in_place
# 1               not_in_place
# 2               not_in_place
# 3               not_in_place
# 4          fully_operational
#                ...
# 140             not_in_place
# 141             not_in_place
# 142    partially_operational
# 143             not_in_place
# 144             not_in_place
# Name: form.ql_isolation_physical_distancing.iso_designated_isolation_for_suspected, Length: 145, dtype: object
# 0      fully_operational
# 1           not_in_place
# 2           not_in_place
# 3      fully_operational
# 4      fully_operational
#              ...
# 140    fully_operational
# 141         not_in_place
# 142    fully_operational
# 143         not_in_place
# 144    fully_operational
# Name: form.ql_isolation_physical_distancing.iso_distance_between_patients_in_waiting, Length: 145, dtype: object
# 0          fully_operational
# 1               not_in_place
# 2      partially_operational
# 3               not_in_place
# 4               not_in_place
#                ...
# 140             not_in_place
# 141             not_in_place
# 142        fully_operational
# 143        fully_operational
# 144        fully_operational
# Name: form.ql_isolation_physical_distancing.iso_distance_between_patient_beds, Length: 145, dtype: object
# 0               not_in_place
# 1      partially_operational
# 2      partially_operational
# 3          fully_operational
# 4          fully_operational
#                ...
# 140        fully_operational
# 141             not_in_place
# 142        fully_operational
# 143        fully_operational
# 144        fully_operational
# Name: form.ql_isolation_physical_distancing.iso_transfer_referral_protocol, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.grp_infection_prevention_and_control.ql_ppe.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1         risk_of_shortage
# 2         risk_of_shortage
# 3      sufficient_supplies
# 4         risk_of_shortage
#               ...
# 140       risk_of_shortage
# 141          not_available
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_medical_masks, Length: 145, dtype: object
# 0            not_available
# 1         risk_of_shortage
# 2      sufficient_supplies
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140       risk_of_shortage
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143          not_available
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_disp_surgical_masks, Length: 145, dtype: object
# 0            not_available
# 1         risk_of_shortage
# 2      sufficient_supplies
# 3      sufficient_supplies
# 4         risk_of_shortage
#               ...
# 140    sufficient_supplies
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143          not_available
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_eye_protection, Length: 145, dtype: object
# 0         risk_of_shortage
# 1         risk_of_shortage
# 2      sufficient_supplies
# 3      sufficient_supplies
# 4         risk_of_shortage
#               ...
# 140       risk_of_shortage
# 141          not_available
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_examination_gloves, Length: 145, dtype: object
# 0         risk_of_shortage
# 1            not_available
# 2         risk_of_shortage
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140       risk_of_shortage
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_surgical_gloves, Length: 145, dtype: object
# 0         risk_of_shortage
# 1            not_available
# 2      sufficient_supplies
# 3      sufficient_supplies
# 4            not_available
#               ...
# 140       risk_of_shortage
# 141          not_available
# 142       risk_of_shortage
# 143          not_available
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_long_cuffed_gloves, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4            not_available
#               ...
# 140          not_available
# 141          not_available
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_heavy_duty_gloves, Length: 145, dtype: object
# 0         risk_of_shortage
# 1            not_available
# 2         risk_of_shortage
# 3         risk_of_shortage
# 4            not_available
#               ...
# 140       risk_of_shortage
# 141          not_available
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_long_sleeved_gown, Length: 145, dtype: object
# 0      sufficient_supplies
# 1      sufficient_supplies
# 2            not_available
# 3      sufficient_supplies
# 4         risk_of_shortage
#               ...
# 140       risk_of_shortage
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_waterproof_aprons, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.choice_labels, Length: 145, dtype: object
# 0      available_fully_achieved
# 1                 not_available
# 2      available_fully_achieved
# 3            partially_achieved
# 4            partially_achieved
#                  ...
# 140    available_fully_achieved
# 141          partially_achieved
# 142          partially_achieved
# 143               not_available
# 144          partially_achieved
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_staff_trained_on_ppe, Length: 145, dtype: object
# 0                 not_available
# 1                 not_available
# 2                 not_available
# 3                 not_available
# 4                 not_available
#                  ...
# 140               not_available
# 141               not_available
# 142               not_available
# 143    available_fully_achieved
# 144          partially_achieved
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_ppe_poster_displayed, Length: 145, dtype: object
# 0           not_available
# 1           not_available
# 2           not_available
# 3           not_available
# 4           not_available
#               ...
# 140         not_available
# 141         not_available
# 142    partially_achieved
# 143         not_available
# 144    partially_achieved
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_fit_test_kit, Length: 145, dtype: object
# 0                 not_available
# 1                 not_available
# 2                 not_available
# 3                 not_available
# 4                 not_available
#                  ...
# 140    available_fully_achieved
# 141               not_available
# 142               not_available
# 143               not_available
# 144               not_available
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_contingency_for_shortages, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2                      nan
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140    sufficient_supplies
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143          not_available
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_colour_coded_bins, Length: 145, dtype: object
# 0         risk_of_shortage
# 1      sufficient_supplies
# 2      sufficient_supplies
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140    sufficient_supplies
# 141       risk_of_shortage
# 142          not_available
# 143       risk_of_shortage
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_clinical_waste_bags, Length: 145, dtype: object
# 0      not_available
# 1      not_available
# 2      not_available
# 3      not_available
# 4      not_available
#            ...
# 140    not_available
# 141    not_available
# 142    not_available
# 143    not_available
# 144    not_available
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_laundry_receptacles_at_patient_rooms, Length: 145, dtype: object
# 0      sufficient_supplies
# 1            not_available
# 2         risk_of_shortage
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140    sufficient_supplies
# 141       risk_of_shortage
# 142    sufficient_supplies
# 143          not_available
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_incinerator, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.choice_labels, Length: 145, dtype: object
# 0      sufficient_supplies
# 1      sufficient_supplies
# 2      sufficient_supplies
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140    sufficient_supplies
# 141    sufficient_supplies
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_clean_running_water, Length: 145, dtype: object
# 0      sufficient_supplies
# 1            not_available
# 2            not_available
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140       risk_of_shortage
# 141    sufficient_supplies
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_hand_soap, Length: 145, dtype: object
# 0      sufficient_supplies
# 1         risk_of_shortage
# 2      sufficient_supplies
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140          not_available
# 141    sufficient_supplies
# 142       risk_of_shortage
# 143          not_available
# 144          not_available
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_liquid_soap, Length: 145, dtype: object
# 0         not_available
# 1         not_available
# 2         not_available
# 3         not_available
# 4         not_available
#              ...
# 140       not_available
# 141       not_available
# 142       not_available
# 143       not_available
# 144    risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_disp_hand_towels, Length: 145, dtype: object
# 0      sufficient_supplies
# 1            not_available
# 2            not_available
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140       risk_of_shortage
# 141    sufficient_supplies
# 142          not_available
# 143          not_available
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_alcohol_based_hand_gel, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4      sufficient_supplies
#               ...
# 140          not_available
# 141       risk_of_shortage
# 142    sufficient_supplies
# 143       risk_of_shortage
# 144    sufficient_supplies
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_facility_disinfection, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140          not_available
# 141       risk_of_shortage
# 142       risk_of_shortage
# 143    sufficient_supplies
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_equipment_sterilisation, Length: 145, dtype: object
# 0      sufficient_supplies
# 1            not_available
# 2            not_available
# 3      sufficient_supplies
# 4      sufficient_supplies
#               ...
# 140          not_available
# 141          not_available
# 142          not_available
# 143          not_available
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_environmental_disinfectant, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4         risk_of_shortage
#               ...
# 140          not_available
# 141          not_available
# 142    sufficient_supplies
# 143    sufficient_supplies
# 144       risk_of_shortage
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_cleaning_schedule_in_toilets, Length: 145, dtype: object
# 0         not_available
# 1         not_available
# 2         not_available
# 3         not_available
# 4         not_available
#              ...
# 140       not_available
# 141    risk_of_shortage
# 142       not_available
# 143       not_available
# 144       not_available
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_corpse_handling, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.ql_logistics_patient_and_sample_transfer.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1      partially_available
# 2      partially_available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142              available
# 143              available
# 144              available
# Name: form.ql_logistics_patient_and_sample_transfer.log_referral_plan, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3                available
# 4                available
#               ...
# 140              available
# 141              available
# 142    partially_available
# 143          not_available
# 144    partially_available
# Name: form.ql_logistics_patient_and_sample_transfer.log_cellphone_landline_swradio, Length: 145, dtype: object
# 0      partially_available
# 1                available
# 2      partially_available
# 3                available
# 4                available
#               ...
# 140          not_available
# 141    partially_available
# 142    partially_available
# 143          not_available
# 144    partially_available
# Name: form.ql_logistics_patient_and_sample_transfer.log_tracer_drugs, Length: 145, dtype: object
# 0      not_available
# 1      not_available
# 2          available
# 3          available
# 4          available
#            ...
# 140        available
# 141        available
# 142        available
# 143        available
# 144        available
# Name: form.ql_logistics_patient_and_sample_transfer.log_albendazole, Length: 145, dtype: object
# 0                available
# 1      partially_available
# 2            not_available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.ql_logistics_patient_and_sample_transfer.log_amoxicillin, Length: 145, dtype: object
# 0            not_available
# 1      partially_available
# 2                available
# 3            not_available
# 4                available
#               ...
# 140    partially_available
# 141          not_available
# 142    partially_available
# 143          not_available
# 144    partially_available
# Name: form.ql_logistics_patient_and_sample_transfer.log_ampicillin, Length: 145, dtype: object
# 0            not_available
# 1                available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140    partially_available
# 141          not_available
# 142          not_available
# 143          not_available
# 144              available
# Name: form.ql_logistics_patient_and_sample_transfer.log_chlorhexidine_5, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140    partially_available
# 141                    nan
# 142          not_available
# 143          not_available
# 144              available
# Name: form.question10.log_chlorhexidine_7, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question10.choice_labels, Length: 145, dtype: object
# 0      partially_available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144              available
# Name: form.question10.log_gentamicin, Length: 145, dtype: object
# 0                available
# 1            not_available
# 2                available
# 3            not_available
# 4            not_available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143          not_available
# 144          not_available
# Name: form.question10.log_folic, Length: 145, dtype: object
# 0                available
# 1            not_available
# 2            not_available
# 3            not_available
# 4            not_available
#               ...
# 140    partially_available
# 141    partially_available
# 142          not_available
# 143          not_available
# 144    partially_available
# Name: form.question10.log_ferrous_and_folic, Length: 145, dtype: object
# 0            not_available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140                    nan
# 141              available
# 142    partially_available
# 143          not_available
# 144          not_available
# Name: form.question10.log_compound_sodium, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140                    nan
# 141              available
# 142    partially_available
# 143              available
# 144          not_available
# Name: form.question10.log_co_trimoxazole_400, Length: 145, dtype: object
# 0          available
# 1      not_available
# 2          available
# 3      not_available
# 4      not_available
#            ...
# 140              nan
# 141    not_available
# 142    not_available
# 143        available
# 144    not_available
# Name: form.question10.log_co_trimoxazole_200, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question6.choice_labels, Length: 145, dtype: object
# 0                available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143          not_available
# 144          not_available
# Name: form.question6.log_metronidazole_250, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4            not_available
#               ...
# 140    partially_available
# 141          not_available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.question6.log_metronidazole_200, Length: 145, dtype: object
# 0      partially_available
# 1                available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140          not_available
# 141              available
# 142              available
# 143              available
# 144    partially_available
# Name: form.question6.log_methyldopa, Length: 145, dtype: object
# 0      partially_available
# 1                available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140          not_available
# 141              available
# 142              available
# 143          not_available
# 144    partially_available
# Name: form.question6.log_magnesium_sulphate, Length: 145, dtype: object
# 0            not_available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141    partially_available
# 142    partially_available
# 143          not_available
# 144    partially_available
# Name: form.question6.log_lidocaine, Length: 145, dtype: object
# 0                available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144    partially_available
# Name: form.question6.log_ibuprofen, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question2.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143    partially_available
# 144    partially_available
# Name: form.question2.log_surgical_spirit, Length: 145, dtype: object
# 0            not_available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144              available
# Name: form.question2.log_sodium_chloride, Length: 145, dtype: object
# 0      partially_available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143          not_available
# 144              available
# Name: form.question2.log_povidone, Length: 145, dtype: object
# 0                available
# 1            not_available
# 2            not_available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143          not_available
# 144              available
# Name: form.question2.log_paracetamol_500, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142          not_available
# 143              available
# 144              available
# Name: form.question2.log_paracetamol_250, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142              available
# 143              available
# 144          not_available
# Name: form.question2.log_ors, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question7.choice_labels, Length: 145, dtype: object
# 0      partially_available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142          not_available
# 143    partially_available
# 144              available
# Name: form.question7.log_gauze, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144          not_available
# Name: form.question7.log_cotton_wool, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2                available
# 3                available
# 4      partially_available
#               ...
# 140    partially_available
# 141              available
# 142          not_available
# 143              available
# 144          not_available
# Name: form.question7.log_cannula_iv_20, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2      partially_available
# 3                available
# 4      partially_available
#               ...
# 140    partially_available
# 141              available
# 142              available
# 143              available
# 144    partially_available
# Name: form.question7.log_cannula_iv_24, Length: 145, dtype: object
# 0            not_available
# 1      partially_available
# 2                available
# 3                available
# 4                available
#               ...
# 140              available
# 141              available
# 142    partially_available
# 143              available
# 144    partially_available
# Name: form.question7.log_zinc_sulphate, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140              available
# 141              available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.question7.log_water, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question4.choice_labels, Length: 145, dtype: object
# 0                available
# 1            not_available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144          not_available
# Name: form.question4.log_needle_23, Length: 145, dtype: object
# 0            not_available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.question4.log_needle_21, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144    partially_available
# Name: form.question4.log_glove_giving, Length: 145, dtype: object
# 0                available
# 1            not_available
# 2                available
# 3                available
# 4      partially_available
#               ...
# 140    partially_available
# 141          not_available
# 142          not_available
# 143          not_available
# 144    partially_available
# Name: form.question4.log_glove_surgical, Length: 145, dtype: object
# 0      partially_available
# 1            not_available
# 2                available
# 3                available
# 4            not_available
#               ...
# 140    partially_available
# 141          not_available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.question4.log_glove_gyn, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4      partially_available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144              available
# Name: form.question4.log_glove_exam, Length: 145, dtype: object
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 140    nan
# 141    nan
# 142    nan
# 143    nan
# 144    nan
# Name: form.question1.choice_labels, Length: 145, dtype: object
# 0            not_available
# 1                available
# 2                available
# 3      partially_available
# 4                available
#               ...
# 140          not_available
# 141    partially_available
# 142    partially_available
# 143          not_available
# 144              available
# Name: form.question1.log_tape, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144              available
# Name: form.question1.log_syringe, Length: 145, dtype: object
# 0                available
# 1                available
# 2                available
# 3                available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144    partially_available
# Name: form.question1.log_oxytocin, Length: 145, dtype: object
# 0            not_available
# 1                available
# 2                available
# 3            not_available
# 4                available
#               ...
# 140    partially_available
# 141              available
# 142    partially_available
# 143              available
# 144    partially_available
# Name: form.question1.log_diazepam, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2                available
# 3                available
# 4      partially_available
#               ...
# 140          not_available
# 141          not_available
# 142          not_available
# 143          not_available
# 144          not_available
# Name: form.question1.log_misoprostol, Length: 145, dtype: object
# 0            not_available
# 1            not_available
# 2            not_available
# 3            not_available
# 4                available
#               ...
# 140          not_available
# 141              available
# 142          not_available
# 143              available
# 144    partially_available
# Name: form.question1.log_glucose, Length: 145, dtype: object
# 0      241.75
# 1       255.5
# 2      583.25
# 3        73.5
# 4         618
#         ...
# 140     544.5
# 141       434
# 142     448.5
# 143    384.25
# 144    243.25
# Name: form.consultations.head_count.monthly_average_head_counts, Length: 145, dtype: object
# 0       149.5
# 1       171.5
# 2         424
# 3       113.5
# 4       292.5
#         ...
# 140    291.75
# 141       334
# 142    403.25
# 143        51
# 144       265
# Name: form.consultations.general_outpatient.monthly_average_general_outpatient, Length: 145, dtype: object
# 0       19.5
# 1      15.75
# 2          9
# 3        6.5
# 4        4.5
#        ...
# 140     17.5
# 141    13.25
# 142       16
# 143     15.5
# 144      5.5
# Name: form.consultations.deliveries.monthly_average_deliveries, Length: 145, dtype: object
# 0         15
# 1      17.25
# 2      19.75
# 3       5.75
# 4       3.25
#        ...
# 140    19.75
# 141    13.25
# 142       21
# 143    16.25
# 144    11.25
# Name: form.consultations.pent_vaccines.monthly_average_pent_vaccines, Length: 145, dtype: object
# 0        2
# 1      1.5
# 2        3
# 3        1
# 4      2.5
#       ...
# 140      2
# 141    1.5
# 142      5
# 143    0.5
# 144    4.5
# Name: form.ql_human_resources.score_human_resources, Length: 145, dtype: object
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 140    5
# 141    5
# 142    5
# 143    5
# 144    5
# Name: form.ql_human_resources.score_max_human_resources, Length: 145, dtype: object
# 0      6
# 1      3
# 2      4
# 3      1
# 4      0
#       ..
# 140    4
# 141    1
# 142    5
# 143    5
# 144    5
# Name: form.ql_information_education_communication.score_information_education_communication, Length: 145, dtype: object
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 140    7
# 141    7
# 142    7
# 143    7
# 144    7
# Name: form.ql_information_education_communication.score_max_information_education_communication, Length: 145, dtype: object
# 0        4
# 1      2.5
# 2      2.5
# 3        3
# 4        3
#       ...
# 140      2
# 141      2
# 142    2.5
# 143    2.5
# 144      3
# Name: form.ql_surveillance.score_surveillance, Length: 145, dtype: object
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 140    4
# 141    4
# 142    4
# 143    4
# 144    4
# Name: form.ql_surveillance.score_max_surveillance, Length: 145, dtype: object
# 0        3
# 1      0.5
# 2      0.5
# 3        2
# 4        2
#       ...
# 140      3
# 141      0
# 142      4
# 143      1
# 144      4
# Name: form.ql_triage_and_early_recognition.score_triage_and_early_recognition, Length: 145, dtype: object
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 140    5
# 141    5
# 142    5
# 143    5
# 144    5
# Name: form.ql_triage_and_early_recognition.score_max_triage_and_early_recognition, Length: 145, dtype: object
# 0      1.5
# 1        1
# 2        1
# 3        2
# 4        3
#       ...
# 140    2.5
# 141      0
# 142    3.5
# 143      1
# 144    3.5
# Name: form.ql_chw.score_chw, Length: 145, dtype: object
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 140    6
# 141    6
# 142    6
# 143    6
# 144    6
# Name: form.ql_chw.score_max_chw, Length: 145, dtype: object
# 0        2
# 1      0.5
# 2        1
# 3        2
# 4        3
#       ...
# 140      2
# 141      0
# 142    3.5
# 143      2
# 144      3
# Name: form.ql_isolation_physical_distancing.score_isolation, Length: 145, dtype: object
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 140    4
# 141    4
# 142    4
# 143    4
# 144    4
# Name: form.ql_isolation_physical_distancing.score_max_isolation, Length: 145, dtype: object
# 0        3
# 1        3
# 2      5.5
# 3      5.5
# 4        3
#       ...
# 140    4.5
# 141      2
# 142    4.5
# 143      6
# 144      5
# Name: form.grp_infection_prevention_and_control.ql_ppe.score_infection_prevention_and_control_ppe, Length: 145, dtype: object
# 0      9
# 1      9
# 2      9
# 3      9
# 4      9
#       ..
# 140    9
# 141    9
# 142    9
# 143    9
# 144    9
# Name: form.grp_infection_prevention_and_control.ql_ppe.score_max_infection_prevention_and_control_ppe, Length: 145, dtype: object
# 0        1
# 1        0
# 2        1
# 3      0.5
# 4      0.5
#       ...
# 140      2
# 141    0.5
# 142      1
# 143      1
# 144    1.5
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.score_infection_prevention_and_control_ppe_plan, Length: 145, dtype: object
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 140    4
# 141    4
# 142    4
# 143    4
# 144    4
# Name: form.grp_infection_prevention_and_control.ql_ppe_plan.score_max_infection_prevention_and_control_ppe_plan, Length: 145, dtype: object
# 0      1.5
# 1        1
# 2      1.5
# 3        0
# 4      1.5
#       ...
# 140      3
# 141    1.5
# 142    1.5
# 143    0.5
# 144      1
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.score_infection_prevention_and_control_waste_collection_and_disposal, Length: 145, dtype: object
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 140    4
# 141    4
# 142    4
# 143    4
# 144    4
# Name: form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.score_max_infection_prevention_and_control_waste_collection_and_disposal, Length: 145, dtype: object
# 0        4
# 1      1.5
# 2        2
# 3        4
# 4        4
#       ...
# 140      2
# 141      4
# 142    1.5
# 143      2
# 144      2
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_infection_prevention_and_control_water_sanitation_and_hygiene, Length: 145, dtype: object
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 140    5
# 141    5
# 142    5
# 143    5
# 144    5
# Name: form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_max_infection_prevention_and_control_water_sanitation_and_hygiene, Length: 145, dtype: object
# 0        1
# 1        0
# 2        0
# 3        2
# 4        3
#       ...
# 140      0
# 141    1.5
# 142    1.5
# 143    1.5
# 144      2
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_infection_prevention_and_control_disinfection_and_sterilization, Length: 145, dtype: object
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 140    5
# 141    5
# 142    5
# 143    5
# 144    5
# Name: form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_max_infection_prevention_and_control_disinfection_and_sterilization, Length: 145, dtype: object
# 0      10.5
# 1       5.5
# 2        10
# 3        12
# 4        12
#        ...
# 140    11.5
# 141     9.5
# 142      10
# 143      11
# 144    11.5
# Name: form.grp_infection_prevention_and_control.score_infection_prevention_and_control, Length: 145, dtype: object
# 0      27
# 1      27
# 2      27
# 3      27
# 4      27
#        ..
# 140    27
# 141    27
# 142    27
# 143    27
# 144    27
# Name: form.grp_infection_prevention_and_control.score_max_infection_prevention_and_control, Length: 145, dtype: object
# 0      19.5
# 1        21
# 2      33.5
# 3      34.5
# 4      29.5
#        ...
# 140    18.5
# 141      32
# 142    16.5
# 143      25
# 144      23
# Name: form.question1.score_logistics_patient_and_sample_transfer, Length: 145, dtype: object
# 0      44
# 1      44
# 2      44
# 3      44
# 4      44
#        ..
# 140    44
# 141    44
# 142    44
# 143    44
# 144    44
# Name: form.question1.score_max_logistics_patient_and_sample_transfer, Length: 145, dtype: object

# %%
hfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 205 entries, Unnamed: 0 to form.score_max_total
# dtypes: float64(4), object(201)
# memory usage: 232.4+ KB

# %%
hfa.to_excel('C:\\Users\\Penelope\\Documents\\ASSIGNMENT\\Health Facility Assessment strip.xlsx')

# %%
types = hfa.dtypes
types.to_list()
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O')]

# %%
#change numerical columns type from object to float
for col in cols:
    hfa[col] = pd.to_numeric(hfa[col], errors='ignore')

# %%
#checking number of float columns
hfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 205 entries, Unnamed: 0 to form.score_max_total
# dtypes: float64(68), int64(2), object(135)
# memory usage: 232.4+ KB

# %%
#I did a manual check on the Excel list using ISNUMBER()
#and there are indeed 72 columns with numerical data 
#so this is now showing correctly

# %%
#get list of which columns are numeric
num_col_list = []
for col in cols:
    is_num = is_numeric_dtype(hfa[col])
    if is_num == True:
        num_col_list.append(col)

# %%
#check the list worked: length and first few columns
print(len(num_col_list))
print(num_col_list[0:6])
# Out:
# 70
# ['Unnamed: 0', 'number', 'form.health_centre_information.facility_type_other', 'form.health_centre_information.capacity.number_consultation_rooms', 'form.health_centre_information.capacity.number_inpatient_beds', 'form.health_centre_information.capacity.number_maternity_beds']

# %%
#get list of which columns are non categorical
cat_col_list = []
for col in cols:
    is_cat = is_string_dtype(hfa[col])
    if is_cat == True:
        cat_col_list.append(col)

# %%
#check the list worked: length and first few columns
print(len(cat_col_list))
print(cat_col_list[0:6])
# Out:
# 135
# ['form.health_centre_information.facility_name', 'form.facility_gps', 'form.health_centre_information.location_information.region_province', 'form.health_centre_information.location_information.district', 'form.health_centre_information.location_information.chiefdom', 'form.health_centre_information.location_information.facility_location']

# %%
#REPLACE "---" WITH "" FOR NUMERICAL LIST

for col in num_col_list:
    hfa[col] = hfa[col].astype('str')
    hfa[col] = hfa[col].str.replace("---","")
    hfa[col] = pd.to_numeric(hfa[col], errors='ignore')

# %%
hfa.head(10)
# Out:
#    Unnamed: 0  number form.health_centre_information.facility_name  \
# 0           0       0                             William hospital
# 1           1       1                         Kathryn Hospital/CHC
# 2           2       2                             Jessica Hospital
# 3           3       3                                   Lauren CHC
# 4           4       4                                    Tammy CHC
# 5           5       5
# 6           6       6                                 Bryan Clinic
# 7           7       7                          Cheryl Hospital/CHC
# 8           8       8                              Brandi hospital
# 9           9       9                    Michael Regional Hospital
#
#          form.facility_gps  \
# 0    60.234598, -90.157892
# 1  21.2454855, -107.509120
# 2     -0.178657, -9.190029
# 3    35.856989, -87.512790
# 4   54.7148835, 150.744813
# 5    22.8567535, 19.262410
# 6    61.8040035, 28.191714
# 7   86.9708915, 173.527045
# 8    77.8973365, 70.112618
# 9    -24.700264, 79.460077
#
#   form.health_centre_information.location_information.region_province  \
# 0                                           Southern
# 1                                           Southern
# 2                                           Southern
# 3                                           Southern
# 4                                           Southern
# 5
# 6                                           Southern
# 7                                           Southern
# 8                                           Southern
# 9                                           Northern
#
#   form.health_centre_information.location_information.district  \
# 0                                            Pujehun
# 1                                                 Bo
# 2                                                 Bo
# 3                                             Bonthe
# 4                                             Bonthe
# 5
# 6                                            Pujehun
# 7                                             Bonthe
# 8                                            Moyamba
# 9                                          Koinadugu
#
#   form.health_centre_information.location_information.chiefdom  \
# 0                                           New York
# 1                                            Arizona
# 2                                         New Mexico
# 3                                           Missouri
# 4                                           Virginia
# 5
# 6                                           Michigan
# 7                                             Nevada
# 8                                            Florida
# 9                                           Arkansas
#
#   form.health_centre_information.location_information.facility_location  \
# 0                                          Jasonfort
# 1                                    West Jamesshire
# 2                                        Robertsside
# 3                                   Port Christopher
# 4                                           Reneeton
# 5
# 6                                          Adammouth
# 7                                       Bryanchester
# 8                                  Port Kristinville
# 9                                         South Adam
#
#   form.health_centre_information.facility_type  \
# 0                        community_health_post
# 1                        community_health_post
# 2                        community_health_post
# 3                                     mch_post
# 4                        community_health_post
# 5
# 6                        community_health_post
# 7                      community_health_centre
# 8                      community_health_centre
# 9                                     mch_post
#
#   form.health_centre_information.facility_type_other  ...  \
# 0                                                nan  ...
# 1                                                nan  ...
# 2                                                nan  ...
# 3                                                nan  ...
# 4                                                nan  ...
# 5                                                nan  ...
# 6                                                nan  ...
# 7                                                nan  ...
# 8                                                nan  ...
# 9                                                nan  ...
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                4.0
# 1                                                1.5
# 2                                                2.0
# 3                                                4.0
# 4                                                4.0
# 5                                                0.0
# 6                                                1.0
# 7                                                3.0
# 8                                                2.5
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
# 5                                                5.0
# 6                                                5.0
# 7                                                5.0
# 8                                                5.0
# 9                                                5.0
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                                3.0
# 5                                                0.0
# 6                                                2.0
# 7                                                1.0
# 8                                                4.0
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
# 5                                                5.0
# 6                                                5.0
# 7                                                5.0
# 8                                                5.0
# 9                                                5.0
#
#   form.grp_infection_prevention_and_control.score_infection_prevention_and_control  \
# 0                                               10.5
# 1                                                5.5
# 2                                               10.0
# 3                                               12.0
# 4                                               12.0
# 5                                                0.0
# 6                                                8.5
# 7                                                7.0
# 8                                               19.5
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.score_max_infection_prevention_and_control  \
# 0                                               27.0
# 1                                               27.0
# 2                                               27.0
# 3                                               27.0
# 4                                               27.0
# 5                                               27.0
# 6                                               27.0
# 7                                               27.0
# 8                                               27.0
# 9                                               27.0
#
#   form.question1.score_logistics_patient_and_sample_transfer  \
# 0                                               19.5
# 1                                               21.0
# 2                                               33.5
# 3                                               34.5
# 4                                               29.5
# 5                                                nan
# 6                                               21.0
# 7                                               15.0
# 8                                               25.0
# 9                                               17.0
#
#   form.question1.score_max_logistics_patient_and_sample_transfer  \
# 0                                               44.0
# 1                                               44.0
# 2                                               44.0
# 3                                               44.0
# 4                                               44.0
# 5                                                nan
# 6                                               44.0
# 7                                               44.0
# 8                                               44.0
# 9                                               44.0
#
#   form.score_total form.score_max_total
# 0             48.5                102.0
# 1             35.5                102.0
# 2             55.5                102.0
# 3             57.5                102.0
# 4             55.0                102.0
# 5              nan                  nan
# 6             53.0                102.0
# 7             38.0                102.0
# 8             65.5                102.0
# 9             17.0                102.0
#
# [10 rows x 205 columns]

# %%
#REPLACE "---" WITH "UNKNOWN" FOR CATEGORICAL LIST

for col in cat_col_list:
    hfa[col] = hfa[col].astype('str')
    hfa[col] = hfa[col].str.replace("---","unknown")

# %%
hfa.head(10)
# Out:
#    Unnamed: 0  number form.health_centre_information.facility_name  \
# 0           0       0                             William hospital
# 1           1       1                         Kathryn Hospital/CHC
# 2           2       2                             Jessica Hospital
# 3           3       3                                   Lauren CHC
# 4           4       4                                    Tammy CHC
# 5           5       5
# 6           6       6                                 Bryan Clinic
# 7           7       7                          Cheryl Hospital/CHC
# 8           8       8                              Brandi hospital
# 9           9       9                    Michael Regional Hospital
#
#          form.facility_gps  \
# 0    60.234598, -90.157892
# 1  21.2454855, -107.509120
# 2     -0.178657, -9.190029
# 3    35.856989, -87.512790
# 4   54.7148835, 150.744813
# 5    22.8567535, 19.262410
# 6    61.8040035, 28.191714
# 7   86.9708915, 173.527045
# 8    77.8973365, 70.112618
# 9    -24.700264, 79.460077
#
#   form.health_centre_information.location_information.region_province  \
# 0                                           Southern
# 1                                           Southern
# 2                                           Southern
# 3                                           Southern
# 4                                           Southern
# 5
# 6                                           Southern
# 7                                           Southern
# 8                                           Southern
# 9                                           Northern
#
#   form.health_centre_information.location_information.district  \
# 0                                            Pujehun
# 1                                                 Bo
# 2                                                 Bo
# 3                                             Bonthe
# 4                                             Bonthe
# 5
# 6                                            Pujehun
# 7                                             Bonthe
# 8                                            Moyamba
# 9                                          Koinadugu
#
#   form.health_centre_information.location_information.chiefdom  \
# 0                                           New York
# 1                                            Arizona
# 2                                         New Mexico
# 3                                           Missouri
# 4                                           Virginia
# 5
# 6                                           Michigan
# 7                                             Nevada
# 8                                            Florida
# 9                                           Arkansas
#
#   form.health_centre_information.location_information.facility_location  \
# 0                                          Jasonfort
# 1                                    West Jamesshire
# 2                                        Robertsside
# 3                                   Port Christopher
# 4                                           Reneeton
# 5
# 6                                          Adammouth
# 7                                       Bryanchester
# 8                                  Port Kristinville
# 9                                         South Adam
#
#   form.health_centre_information.facility_type  \
# 0                        community_health_post
# 1                        community_health_post
# 2                        community_health_post
# 3                                     mch_post
# 4                        community_health_post
# 5
# 6                        community_health_post
# 7                      community_health_centre
# 8                      community_health_centre
# 9                                     mch_post
#
#   form.health_centre_information.facility_type_other  ...  \
# 0                                                nan  ...
# 1                                                nan  ...
# 2                                                nan  ...
# 3                                                nan  ...
# 4                                                nan  ...
# 5                                                nan  ...
# 6                                                nan  ...
# 7                                                nan  ...
# 8                                                nan  ...
# 9                                                nan  ...
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                4.0
# 1                                                1.5
# 2                                                2.0
# 3                                                4.0
# 4                                                4.0
# 5                                                0.0
# 6                                                1.0
# 7                                                3.0
# 8                                                2.5
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
# 5                                                5.0
# 6                                                5.0
# 7                                                5.0
# 8                                                5.0
# 9                                                5.0
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                                3.0
# 5                                                0.0
# 6                                                2.0
# 7                                                1.0
# 8                                                4.0
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
# 5                                                5.0
# 6                                                5.0
# 7                                                5.0
# 8                                                5.0
# 9                                                5.0
#
#   form.grp_infection_prevention_and_control.score_infection_prevention_and_control  \
# 0                                               10.5
# 1                                                5.5
# 2                                               10.0
# 3                                               12.0
# 4                                               12.0
# 5                                                0.0
# 6                                                8.5
# 7                                                7.0
# 8                                               19.5
# 9                                                0.0
#
#   form.grp_infection_prevention_and_control.score_max_infection_prevention_and_control  \
# 0                                               27.0
# 1                                               27.0
# 2                                               27.0
# 3                                               27.0
# 4                                               27.0
# 5                                               27.0
# 6                                               27.0
# 7                                               27.0
# 8                                               27.0
# 9                                               27.0
#
#   form.question1.score_logistics_patient_and_sample_transfer  \
# 0                                               19.5
# 1                                               21.0
# 2                                               33.5
# 3                                               34.5
# 4                                               29.5
# 5                                                nan
# 6                                               21.0
# 7                                               15.0
# 8                                               25.0
# 9                                               17.0
#
#   form.question1.score_max_logistics_patient_and_sample_transfer  \
# 0                                               44.0
# 1                                               44.0
# 2                                               44.0
# 3                                               44.0
# 4                                               44.0
# 5                                                nan
# 6                                               44.0
# 7                                               44.0
# 8                                               44.0
# 9                                               44.0
#
#   form.score_total form.score_max_total
# 0             48.5                102.0
# 1             35.5                102.0
# 2             55.5                102.0
# 3             57.5                102.0
# 4             55.0                102.0
# 5              nan                  nan
# 6             53.0                102.0
# 7             38.0                102.0
# 8             65.5                102.0
# 9             17.0                102.0
#
# [10 rows x 205 columns]

# %%
####################################################################################################3

# %%
#come back to fix inconsistent columns: nothern

# %%
###################################################################################################

# %%
#categorical data

# %%
ordinal_encoder = OrdinalEncoder()

# %%
hfa[cat_col_list] = ordinal_encoder.fit_transform(hfa[cat_col_list])

# %%
hfa.isnull().sum().sum()
# Out:
# 0

# %%
#####################################################################################################

# %%
# Imputation
my_imputer = SimpleImputer()
imputed_hfa = pd.DataFrame(my_imputer.fit_transform(hfa))

# %%
hfa.isnull().sum().sum()
# Out:
# 0

# %%
hfa.to_excel('C:\\Users\\Penelope\\Documents\\ASSIGNMENT\\Health Facility Assessment strip.xlsx')
