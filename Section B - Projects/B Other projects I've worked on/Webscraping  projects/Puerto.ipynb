# %% [markdown]
# Figure out points
# Copy info
# count vp per player
# how to catch just the new stuff and not readd to the old?
#     ctrl a

# %%
notes = ['JBC1 earned 1 victory point for shipping',
'PenelopeHB earned 1 victory point from their harbor',
'PenelopeHB earned 2 victory points for shipping (wharf)',
'JBC1 earned 1 victory point as their privilege',
'JBC1 earned 2 victory points for shipping']


name1 = "JBC"
name2 = "Pen"
points1 = 0
points2 = 0
players = {}

for string in notes:
    name = string[0:3]
    print(name)
    if name == 'JBC':
        points = string[12]
    elif name == "Pen":
        points = string[18]
    players[name] = points
    print(players)
# Out:
# JBC
# {'JBC': '1'}
# Pen
# {'JBC': '1', 'Pen': '1'}
# Pen
# {'JBC': '1', 'Pen': '2'}
# JBC
# {'JBC': '1', 'Pen': '2'}
# JBC
# {'JBC': '2', 'Pen': '2'}

# %%
notes = ['PenelopeHB earned 5 victory point from their harbor',
'JBC1 earned 3 victory point as their privilege',
'PenelopeHB earned 9 victory points for shipping (wharf)',
'JBC1 earned 4 victory points for shipping']


name1 = "JBC"
name2 = "Pen"
JBC_points = 0
Pen_points = 0

for string in notes:
    name = string[0:3]

    if name == 'JBC':
        new_points = int(string[12])
        JBC_points += new_points
    elif name == "Pen":
        new_points = int(string[18])
        Pen_points += new_points
    print(f"JBC:{JBC_points}  Pen:{Pen_points}\n")
    
    #need to only do this for lines that include victory points
    #nested if? if JBC string[xyz] = victory etc...
    #also need to sort the other way around as the lines come in with the latest at the top...
    #they are named logs!
# Out:
# JBC:0  Pen:5
#
# JBC:3  Pen:5
#
# JBC:3  Pen:14
#
# JBC:7  Pen:14

# %%
check = ['PenelopeHB earned 9 victory points for shipping (wharf)',
'JBC1 earned 4 victory points for shipping']

string1 = check[0]
string1.find("victory")
# Out:
# 20

# %%
notes = ['PenelopeHB earned 5 victory point from their harbor',
'JBC1 earned 3 victory point as their privilege',
'PenelopeHB earned 9 victory points for shipping (wharf)',
'This is a test',
'JBC1 earned 4 victory points for shipping',
'Anna earned 2 victory points for shipping']


name1 = "Pen"
name2 = ""
name3 = ""
name4 = ""
name5 = ""
points1 = 0
points2 = 0
points3 = 0
points4 = 0
points5 = 0
ids = ['name2', 'name3', 'name4', 'name5']
players = {}

players[name1] = points1

for line in notes:
    if line.find("victory")>0:
        
        if line[0:3] == name1:
            index = line.find("victory")
            new_points1 = int(line[index-2])
            print(f"{name1} new_points {new_points1}")

            points1 = points1 + new_points1
            players[name1] = points1
            print(players)
            print("\n")
            
        elif line[0:3] != name1:
            print(ids[0])
            line[0:3] == ids[0]
            print(ids)
            ids.pop(0)
            print(ids)
            #name2 = line[0:3]
                
            index = line.find("victory")
            new_points2 = int(line[index-2])
            print(f"{name2} new_points {new_points2}")

            points2 = points2 + new_points2
            players[name2] = points2
            print(players)
            print("\n")
            
        elif line[0:3] != name1 and line[0:3] != name2:
            ids[0] = line[0:3]
            ids.pop(0)
            print(ids)
            name3 = line[0:3]
            print("newname")
                
            index = line.find("victory")
            new_points3 = int(line[index-2])
            print(f"{name3} new_points {new_points3}")
            print(points3)
            points3 = points3 + new_points3
            players[name3] = points3
            print(players)
            print("\n")

    else:
        pass
    
#the problem is that once ann comes along its not equal to name1 so it gets assigned name2 
#maybe do something like the spy game with a list of name1,name2,name3 etc and pop off as they get assigned?
# Out:
# Pen new_points 5
# {'Pen': 5}
#
#
# name2
# ['name2', 'name3', 'name4', 'name5']
# ['name3', 'name4', 'name5']
#  new_points 3
# {'Pen': 5, '': 3}
#
#
# Pen new_points 9
# {'Pen': 14, '': 3}
#
#
# name3
# ['name3', 'name4', 'name5']
# ['name4', 'name5']
#  new_points 4
# {'Pen': 14, '': 7}
#
#
# name4
# ['name4', 'name5']
# ['name5']
#  new_points 2
# {'Pen': 14, '': 9}

# %%
ids = [name1, name2, name3, name4, name5]
print(ids)

for id in ids:
    ids.pop(0)
    print(ids)
# Out:
# ['Pen', 'Ann', '', '', '']
# ['Ann', '', '', '']
# ['', '', '']
# ['', '']

# %%
notes = ['PenelopeHB earned 5 victory point from their harbor',
'JBC1 earned 3 victory point as their privilege',
'Anna earned 1 victory points for shipping',
'PenelopeHB earned 9 victory points for shipping (wharf)',
'JBC1 earned 4 victory points for shipping',
'Anna earned 2 victory points for shipping']

ids = ["name2", "name3", "name4", "name5"]

name1 = "Pen"

for line in notes:
    if line[0:3] != name1 and line[0:3] != name2:
        print(f"name is {line[0:3]}")
        print(f"ids are {ids}")
        print("not equal")
        print(f"id[0] is {ids[0]}")
        ids[0] = line[0:3]
        print(f"id[0] is {ids[0]}")
        ids.pop(0)
        print(f"ids are {ids}")
        print(name2)
        print("\n")
    else:
        print(name1)
        print("\n")
# Out:
# Pen
#
#
# name is JBC
# ids are ['name2', 'name3', 'name4', 'name5']
# not equal
# id[0] is name2
# id[0] is JBC
# ids are ['name3', 'name4', 'name5']
#
#
#
# name is Ann
# ids are ['name3', 'name4', 'name5']
# not equal
# id[0] is name3
# id[0] is Ann
# ids are ['name4', 'name5']
#
#
#
# Pen
#
#
# name is JBC
# ids are ['name4', 'name5']
# not equal
# id[0] is name4
# id[0] is JBC
# ids are ['name5']
#
#
#
# name is Ann
# ids are ['name5']
# not equal
# id[0] is name5
# id[0] is Ann
# ids are []

# %%
#TRYING AGAIN BELOW

# %%
notes = ['Table #88453632',
'Move #294',
'Progression 83%',
'Waiting for all players to finish harvest phase',
'Player Aid',
'   Get back to tables list    ',
'This player is not playing: what can I do?',
'×34',
'Shack Builder',
'Each farm extension costs 1 less farm good.',
'Your Farm ( 7, 52, ',
'10, )                                                                                                                                 ',
'Joiner',
'You may pay for roof markers with upgraded goods.',
'3 silver',
'4 silver',
'5 silver',
'Peddler',
'When one of your markers is removed from the market, you may immediately relocate it to an adjacent, empty space.',
'Gardener',
'Place 1 harvest good from a den or field together with a marker from your pool onto this card. You may use them later as any kind of harvest good.',
'Negotiator',
'Each time one of your markers is removed from the market, take a victory point.',
'Blacksmith',
'Advance 1 additional step on the siesta track in step 2 of the transportation phase.',
'Foreman',
'When another player uses a die with the same number as a die that is already on your farm, take 1 silver.',
'Trader',
'Spend one trade commodity to receive any 3 harvest goods or 7 silver.',
'Tenant',
'After the dice are rolled, take 1 die and place it in front of you. You may use it for free. Any other player must pay you 1 farm good or 2 silver to take and use it.',
'Market Woman',
'Each time you return 1 trade commodity you may spend 3 silver to take 2 different revenues.',
'Supplier',
'When you make a delivery to a market barrow; you may make 1 free delivery to a craft building.',
'MandelMarie Farm ( 20, 52, ',
'18, )                                                                                                                                 ',
'Pig Breeder',
'When you have at least 3 pigs and enough space, receive 2 offspring at the start of step 3 of the farm phase.',
'Straw Binder',
'When you buy a roof marker, advance 1 step on the siesta track.',
'Porter',
'When you choose revenue space 2 or 6, take 2 different revenues from that space.',
'Farm Servant',
'Perform 1 free upgrade.',
'Wagoner Servant',
'When you make a delivery to a craft building you may make 1 free delivery to a market barrow.',
'Candle Maker',
'When you use a die to take at least 1 harvest good, take 2 silver.',
'Haggler',
'When you fully supply a craft building, you may return 1 delivered good back to your farm.',
'La Granja',
'How to play?',
'',
'Competition',
'',
'Strategy tips',
'',
'Options',
'',
'Credits',
'',
'RANKING',
'Current Season ',
'1st',
' gantemian',
'1',
'1817',
'2nd',
' salemome',
'2',
'1814',
'3rd',
' Zaibor',
'3',
'1724',
'4th',
' pottodesu',
'4',
'1716',
'5th',
' Fifty_grosz',
'5',
'1697',
'6th',
' Corbz',
'6',
'1684',
'7th',
' Faceman127',
'7',
'1674',
'8th',
' firstgrader',
'8',
'1659',
'9th',
' Seg2017',
'9',
'1658',
'10th',
' slywww2020',
'10',
'1635',
'',
'  Display more...',
'MY ACHIEVEMENTS',
' 1',
'  (not ranked)',
'3 Games',
'0 Victories',
'',
' My statistics for this game',
'',
'Show achievement details',
'PenelopeHB',
'52  • ',
' 1',
'7 ',
'52 ',
'4',
'MandelMarie',
'52  • ',
' 62',
'20 ',
'52 ',
'6',
'TOP ',
'BGA',
'Help',
'What is Board Game Arena?',
'Who are we?',
'F.A.Q.',
'Contact us',
'Contribute',
'Game publishers',
'Game developers',
'Contribute to BGA',
'Report a bug',
'Go Premium!',
'Follow us',
' Join us on Facebook',
' Follow us on Twitter',
' Notify your browser',
' Subscribe to News',
'Board Game Arena Release 200603-1012 • Legal infoπ',
'Game log',
'5/19/2020',
'The colors of MandelMarie have been chosen according to their preferences. Change my preferences.         ',
'07:47 AM',
'A new round begins!         ',
'07:47 AM',
'MandelMarie plays card 27 as extension         ',
'08:05 AM',
'MandelMarie pays 1 vp          ',
'08:05 AM',
'MandelMarie plays helper Farm Servant         ',
'08:08 AM',
'MandelMarie draws 2 cards         ',
'08:08 AM',
'MandelMarie receives 1 silver         ',
'08:08 AM',
'MandelMarie collects no pig offspring         ',
'08:08 AM',
'PenelopeHB plays card 14 as field         ',
'10:06 AM',
'PenelopeHB plays card 33 as field         ',
'10:07 AM',
'PenelopeHB returns a trade commodity         ',
'10:08 AM',
'PenelopeHB plays card 46 as barrow         ',
'10:08 AM',
'PenelopeHB draws 2 cards         ',
'10:08 AM',
'PenelopeHB collects no income         ',
'10:08 AM',
'PenelopeHB fields grow         ',
'10:08 AM',
'PenelopeHB collects no pig offspring         ',
'10:09 AM',
'MandelMarie buys a roof marker         ',
'01:15 PM',
'MandelMarie pays 1 silver         ',
'01:15 PM',
'PenelopeHB buys a roof marker         ',
'05:27 PM',
'PenelopeHB pays 1 silver         ',
'05:27 PM',
'PenelopeHB activates a roof         ',
'05:27 PM',
'PenelopeHB receives a pig         ',
'05:27 PM',
'Revenue dice rolled         ',
'05:27 PM',
'PenelopeHB takes a 5-value die          ',
'05:28 PM',
'PenelopeHB upgrades pig to meat         ',
'05:29 PM',
'PenelopeHB upgrades grain to food         ',
'05:29 PM',
'5/20/2020',
'MandelMarie activates a roof         ',
'12:36 PM',
'MandelMarie plays helper Porter         ',
'12:36 PM',
'MandelMarie takes a 2-value die          ',
'12:38 PM',
'MandelMarie activates helper Porter         ',
'12:38 PM',
'MandelMarie takes a olive         ',
'12:38 PM',
'MandelMarie plays card 30 as barrow         ',
'12:39 PM',
'MandelMarie activates helper Farm Servant         ',
'12:39 PM',
'MandelMarie upgrades olive to food         ',
'12:39 PM',
'5/21/2020',
'PenelopeHB takes a 6-value die          ',
'04:38 PM',
'PenelopeHB receives 2 silver         ',
'04:38 PM',
'MandelMarie takes a 3-value die          ',
'07:09 PM',
'MandelMarie takes a olive         ',
'07:09 PM',
'MandelMarie takes a grape         ',
'07:09 PM',
'5/22/2020',
'PenelopeHB takes a grape         ',
'07:52 AM',
'PenelopeHB takes a grain         ',
'07:52 AM',
'MandelMarie takes a grape         ',
'08:17 AM',
'MandelMarie takes a olive         ',
'08:17 AM',
'PenelopeHB reveals ',
'         ',
'11:45 AM',
'PenelopeHB advances 1 step(s) on the siesta track         ',
'11:45 AM',
'MandelMarie reveals ',
'         ',
'11:45 AM',
'MandelMarie advances 2 step(s) on the siesta track         ',
'11:45 AM',
'5/24/2020',
'MandelMarie delivers a olive to a barrow         ',
'08:37 PM',
'MandelMarie delivers a food to a barrow         ',
'08:37 PM',
'MandelMarie sells a grape         ',
'08:39 PM',
'MandelMarie receives 2 silver         ',
'08:39 PM',
'5/25/2020',
'PenelopeHB delivers a food to a barrow         ',
'04:57 PM',
'PenelopeHB delivers a meat to a barrow         ',
'04:57 PM',
'PenelopeHB delivers a grape to a barrow         ',
'04:59 PM',
'5/26/2020',
'MandelMarie buys 0 extra deliveries         ',
'08:17 AM',
'PenelopeHB buys 0 extra deliveries         ',
'11:51 AM',
'PenelopeHB receives 1 vp ( 0vp from siesta track / 1vp from markers in the market )         ',
'11:51 AM',
'MandelMarie receives 2 vp ( 1vp from siesta track / 1vp from markers in the market )         ',
'11:51 AM',
'A new round begins!         ',
'11:51 AM',
'PenelopeHB upgrades a olive to food         ',
'11:52 AM',
'PenelopeHB pays 2 silver         ',
'11:52 AM',
'MandelMarie plays card 62 as field         ',
'12:37 PM',
'MandelMarie draws 3 cards         ',
'12:38 PM',
'MandelMarie receives 1 silver         ',
'12:38 PM',
'MandelMarie fields grow         ',
'12:39 PM',
'MandelMarie collects no pig offspring         ',
'12:39 PM',
'5/27/2020',
'PenelopeHB plays card 22 as field         ',
'09:58 AM',
'PenelopeHB draws 1 cards         ',
'09:58 AM',
'PenelopeHB collects no income         ',
'09:58 AM',
'PenelopeHB fields grow         ',
'09:58 AM',
'PenelopeHB collects no pig offspring         ',
'09:58 AM',
'5/29/2020',
'MandelMarie buys a roof marker         ',
'08:06 AM',
'MandelMarie receives 1 vp          ',
'08:06 AM',
'MandelMarie pays 2 silver         ',
'08:06 AM',
'5/30/2020',
'PenelopeHB skips buying a roof         ',
'03:42 PM',
'Revenue dice rolled         ',
'03:42 PM',
'MandelMarie takes a 3-value die          ',
'05:17 PM',
'MandelMarie takes a grape         ',
'05:17 PM',
'MandelMarie takes a olive         ',
'05:17 PM',
'PenelopeHB takes a 5-value die          ',
'06:09 PM',
'PenelopeHB upgrades grain to food         ',
'06:09 PM',
'PenelopeHB upgrades grape to wine         ',
'06:09 PM',
'5/31/2020',
'MandelMarie takes a 4-value die          ',
'08:22 AM',
'MandelMarie receives 4 silver         ',
'08:22 AM',
'PenelopeHB takes a 4-value die          ',
'03:07 PM',
'PenelopeHB receives 4 silver         ',
'03:07 PM',
'43836',
'MandelMarie receives 4 silver         ',
'12:34 PM',
'PenelopeHB receives 4 silver         ',
'03:59 PM',
'43867',
'MandelMarie reveals ',
'         ',
'08:43 AM',
'PenelopeHB reveals ',
'         ',
'08:43 AM',
'MandelMarie pays 1 silver         ',
'08:43 AM',
'MandelMarie delivers a silver to a craft building         ',
'08:43 AM',
'MandelMarie pays 1 silver         ',
'08:43 AM',
'MandelMarie delivers a silver to a craft building         ',
'08:43 AM',
'MandelMarie pays 1 silver         ',
'08:43 AM',
'MandelMarie delivers a silver to a craft building         ',
'08:43 AM',
'MandelMarie pays 1 silver         ',
'08:44 AM',
'MandelMarie delivers a silver to a craft building         ',
'08:44 AM',
'MandelMarie activates helper Farm Servant         ',
'08:44 AM',
'MandelMarie upgrades grain to food         ',
'08:44 AM',
'PenelopeHB cancels their move         ',
'10:56 AM',
'PenelopeHB delivers a wine to a barrow         ',
'10:56 AM',
'PenelopeHB has fully supplied a market barrow.         ',
'10:56 AM',
'PenelopeHB places a marker in the market and gets a trade commodity         ',
'10:56 AM',
'PenelopeHB receives 7 vp ( 6vp market barrow value / 1vp booting marker )         ',
'10:56 AM',
'PenelopeHB pays 1 silver         ',
'10:56 AM',
'PenelopeHB delivers a silver to a craft building         ',
'10:56 AM',
'PenelopeHB pays 1 silver         ',
'10:56 AM',
'PenelopeHB delivers a silver to a craft building         ',
'10:56 AM',
'PenelopeHB pays 1 silver         ',
'10:56 AM',
'PenelopeHB delivers a silver to a craft building         ',
'10:56 AM',
'MandelMarie buys 1 extra deliveries         ',
'01:02 PM',
'MandelMarie pays 1 silver         ',
'01:02 PM',
'MandelMarie pays 1 silver         ',
'01:03 PM',
'MandelMarie delivers a silver to a craft building         ',
'01:03 PM',
'PenelopeHB buys 1 extra deliveries         ',
'01:04 PM',
'PenelopeHB pays 1 silver         ',
'01:04 PM',
'PenelopeHB pays 1 silver         ',
'01:04 PM',
'PenelopeHB delivers a silver to a craft building         ',
'01:04 PM',
'PenelopeHB receives 2 vp ( 0vp from siesta track / 2vp from markers in the market )         ',
'01:04 PM',
'MandelMarie receives 0 vp ( 0vp from siesta track / 0vp from markers in the market )         ',
'01:04 PM',
'A new round begins!         ',
'01:04 PM',
'PenelopeHB plays card 9 as barrow         ',
'01:07 PM',
'PenelopeHB draws 1 cards         ',
'01:08 PM',
'PenelopeHB collects no income         ',
'01:08 PM',
'PenelopeHB fields grow         ',
'01:08 PM',
'PenelopeHB collects no pig offspring         ',
'01:08 PM',
'43896',
'MandelMarie plays card 53 as barrow         ',
'07:16 AM',
'MandelMarie draws 1 cards         ',
'07:16 AM',
'MandelMarie receives 1 silver         ',
'07:16 AM',
'MandelMarie fields grow         ',
'07:17 AM',
'MandelMarie collects no pig offspring         ',
'07:17 AM',
'MandelMarie buys a roof marker         ',
'07:18 AM',
'MandelMarie receives 2 vp          ',
'07:18 AM',
'MandelMarie pays 3 silver         ',
'07:18 AM',
'PenelopeHB skips buying a roof         ',
'01:27 PM',
'Revenue dice rolled         ',
'01:30 PM',
'43957',
'MandelMarie takes a 6-value die          ',
'08:32 AM',
'MandelMarie pays 1 silver         ',
'08:32 AM',
'MandelMarie delivers a silver to a craft building         ',
'08:32 AM',
'MandelMarie unlocks the next craft building         ',
'08:32 AM',
'MandelMarie has fully supplied the merchant house         ',
'08:32 AM',
'MandelMarie receives 5 vp ( 3vp based on round value / 1vp first to complete this craft building / 1vp unlocking next building )         ',
'08:32 AM',
'MandelMarie gets ',
'         ',
'08:32 AM',
'MandelMarie receives 3 silver         ',
'08:32 AM',
'MandelMarie activates helper Porter         ',
'08:33 AM',
'MandelMarie receives 2 silver         ',
'08:33 AM',
'PenelopeHB takes a 2-value die          ',
'09:38 AM',
'PenelopeHB plays card 64 as extension         ',
'01:43 PM',
'MandelMarie takes a 3-value die          ',
'03:19 PM',
'MandelMarie takes a grape         ',
'03:19 PM',
'MandelMarie takes a olive         ',
'03:19 PM',
'PenelopeHB takes a 4-value die          ',
'09:17 PM',
'PenelopeHB receives 4 silver         ',
'09:17 PM',
'43988',
'MandelMarie receives 4 silver         ',
'09:57 AM',
'MandelMarie activates helper Farm Servant         ',
'09:58 AM',
'MandelMarie upgrades grain to food         ',
'09:58 AM',
'PenelopeHB receives 4 silver         ',
'10:10 AM',
'MandelMarie reveals ',
'         ',
'01:24 PM',
'MandelMarie advances 1 step(s) on the siesta track         ',
'01:24 PM',
'PenelopeHB reveals ',
'         ',
'01:24 PM',
'PenelopeHB advances 2 step(s) on the siesta track         ',
'01:24 PM',
'PenelopeHB pays 1 silver         ',
'01:25 PM',
'PenelopeHB delivers a silver to a craft building         ',
'01:25 PM',
'PenelopeHB pays 1 silver         ',
'01:25 PM',
'PenelopeHB delivers a silver to a craft building         ',
'01:25 PM',
'PenelopeHB has fully supplied the merchant house         ',
'01:25 PM',
'PenelopeHB receives 3 vp          ',
'01:25 PM',
'PenelopeHB gets ',
'         ',
'01:25 PM',
'PenelopeHB receives 3 silver         ',
'01:25 PM',
'44018',
'MandelMarie activates a roof         ',
'09:45 PM',
'MandelMarie receives a pig         ',
'09:45 PM',
'MandelMarie delivers a pig to a barrow         ',
'09:45 PM',
'MandelMarie has fully supplied a market barrow.         ',
'09:45 PM',
'MandelMarie places a marker in the market and gets a trade commodity         ',
'09:45 PM',
'MandelMarie receives 5 vp ( 4vp market barrow value / 1vp booting marker )         ',
'09:45 PM',
'MandelMarie delivers a olive to a barrow         ',
'09:45 PM',
'MandelMarie delivers a olive to a barrow         ',
'09:45 PM',
'44049',
'PenelopeHB buys 2 extra deliveries         ',
'09:14 AM',
'PenelopeHB pays 2 silver         ',
'09:14 AM',
'PenelopeHB delivers a grape to a barrow         ',
'09:14 AM',
'PenelopeHB delivers a food to a barrow         ',
'09:14 AM',
'PenelopeHB has fully supplied a market barrow.         ',
'09:14 AM',
'PenelopeHB places a marker in the market and gets a trade commodity         ',
'09:15 AM',
'PenelopeHB receives 2 vp          ',
'09:15 AM',
'PenelopeHB returns a trade commodity         ',
'09:15 AM',
'PenelopeHB receives a pig         ',
'09:15 AM',
'PenelopeHB returns a trade commodity         ',
'09:16 AM',
'PenelopeHB receives a pig         ',
'09:16 AM',
'PenelopeHB upgrades a grain to food         ',
'09:16 AM',
'PenelopeHB pays 2 silver         ',
'09:16 AM',
'MandelMarie buys 1 extra deliveries         ',
'01:30 PM',
'MandelMarie pays 1 silver         ',
'01:30 PM',
'MandelMarie delivers a grape to a barrow         ',
'01:30 PM',
'PenelopeHB receives 3 vp ( 1vp from siesta track / 2vp from markers in the market )         ',
'01:32 PM',
'MandelMarie receives 1 vp ( 0vp from siesta track / 1vp from markers in the market )         ',
'01:32 PM',
'A new round begins!         ',
'01:32 PM',
'MandelMarie plays card 63 as barrow         ',
'01:33 PM',
'MandelMarie draws 1 cards         ',
'01:34 PM',
'MandelMarie receives 4 silver         ',
'01:34 PM',
'MandelMarie fields grow         ',
'01:34 PM',
'MandelMarie collects no pig offspring         ',
'01:34 PM',
'PenelopeHB plays card 57 as barrow         ',
'02:44 PM',
'PenelopeHB draws 3 cards         ',
'02:45 PM',
'PenelopeHB receives 3 silver         ',
'02:45 PM',
'PenelopeHB fields grow         ',
'02:45 PM',
'PenelopeHB receives pig offspring         ',
'02:45 PM',
'PenelopeHB buys a roof marker         ',
'02:46 PM',
'PenelopeHB receives 1 vp          ',
'02:46 PM',
'PenelopeHB pays 4 silver         ',
'02:46 PM',
'MandelMarie buys a roof marker         ',
'10:45 PM',
'MandelMarie receives 3 vp          ',
'10:45 PM',
'MandelMarie pays 4 silver         ',
'10:45 PM',
'Revenue dice rolled         ',
'10:46 PM',
'44080',
'PenelopeHB takes a 4-value die          ',
'02:33 PM',
'PenelopeHB receives 4 silver         ',
'02:33 PM',
'44110',
'MandelMarie takes a 2-value die          ',
'06:40 AM',
'MandelMarie activates helper Porter         ',
'06:40 AM',
'MandelMarie plays card 6 as barrow         ',
'06:40 AM',
'MandelMarie takes a olive         ',
'06:41 AM',
'PenelopeHB takes a 5-value die          ',
'02:28 PM',
'PenelopeHB upgrades pig to meat         ',
'02:29 PM',
'PenelopeHB upgrades grape to wine         ',
'02:29 PM',
'MandelMarie cancels their move         ',
'06:30 PM',
'MandelMarie takes a 6-value die          ',
'06:32 PM',
'MandelMarie delivers a grain to a barrow         ',
'06:44 PM',
'MandelMarie activates helper Farm Servant         ',
'06:45 PM',
'MandelMarie upgrades grape to wine         ',
'06:45 PM',
'PenelopeHB delivers a grain to a barrow         ',
'09:12 PM',
'44141',
'MandelMarie delivers a olive to a barrow         ',
'10:44 AM',
'MandelMarie has fully supplied a market barrow.         ',
'10:44 AM',
'MandelMarie places a marker in the market and gets a trade commodity         ',
'10:44 AM',
'MandelMarie receives 2 vp          ',
'10:44 AM',
'PenelopeHB reveals ',
'         ',
'03:16 PM',
'PenelopeHB advances 1 step(s) on the siesta track         ',
'03:16 PM',
'MandelMarie reveals ',
'         ',
'03:16 PM',
'PenelopeHB delivers a meat to a barrow         ',
'03:17 PM',
'PenelopeHB delivers a olive to a craft building         ',
'03:18 PM',
'PenelopeHB delivers a grain to a craft building         ',
'03:18 PM',
'MandelMarie delivers a trade commodity to a craft building         ',
'03:26 PM',
'6/13/2020',
'MandelMarie delivers a trade commodity to a craft building         ',
'08:41 AM',
'MandelMarie delivers a trade commodity to a craft building         ',
'08:41 AM',
'MandelMarie unlocks the next craft building         ',
'08:41 AM',
'MandelMarie has fully supplied the deli         ',
'08:41 AM',
'MandelMarie receives 6 vp ( 4vp based on round value / 1vp first to complete this craft building / 1vp unlocking next building )         ',
'08:41 AM',
'MandelMarie gets ',
'         ',
'08:41 AM',
'MandelMarie gets a trade commodity         ',
'08:41 AM',
'MandelMarie delivers a food to a barrow         ',
'08:41 AM',
'PenelopeHB cancels their move         ',
'06:00 PM',
'PenelopeHB buys 2 extra deliveries         ',
'06:01 PM',
'PenelopeHB pays 2 silver         ',
'06:01 PM',
'PenelopeHB delivers a food to a craft building         ',
'06:01 PM',
'PenelopeHB delivers a wine to a craft building         ',
'06:02 PM',
'MandelMarie buys 1 extra deliveries         ',
'10:35 PM',
'MandelMarie pays 1 silver         ',
'10:35 PM',
'MandelMarie delivers a wine to a barrow         ',
'10:35 PM',
'PenelopeHB receives 2 vp ( 0vp from siesta track / 2vp from markers in the market )         ',
'10:36 PM',
'MandelMarie receives 2 vp ( 0vp from siesta track / 2vp from markers in the market )         ',
'10:36 PM',
'A new round begins!         ',
'10:36 PM',
'MandelMarie plays card 45 as barrow         ',
'10:37 PM',
'MandelMarie draws 2 cards         ',
'10:37 PM',
'MandelMarie gets a trade commodity         ',
'10:37 PM',
'MandelMarie receives 4 silver         ',
'10:37 PM',
'MandelMarie fields grow         ',
'10:37 PM',
'MandelMarie collects no pig offspring         ',
'10:38 PM',
'6/14/2020',
'PenelopeHB plays helper Gardener         ',
'04:41 PM',
'PenelopeHB draws 1 cards         ',
'04:42 PM',
'PenelopeHB receives 3 silver         ',
'04:42 PM',
'PenelopeHB fields grow         ',
'04:42 PM',
'PenelopeHB receives pig offspring         ',
'04:42 PM',
'PenelopeHB activates helper Gardener         ',
'04:44 PM',
'PenelopeHB activates a roof         ',
'04:44 PM',
'PenelopeHB upgrades pig to meat         ',
'04:44 PM',
'PenelopeHB buys a roof marker         ',
'04:46 PM',
'PenelopeHB receives 2 vp          ',
'04:46 PM',
'PenelopeHB pays 5 silver         ',
'04:46 PM',
'MandelMarie buys a roof marker         ',
'07:57 PM',
'MandelMarie receives 4 vp          ',
'07:57 PM',
'MandelMarie pays 5 silver         ',
'07:57 PM',
'Revenue dice rolled         ',
'07:57 PM',
'PenelopeHB takes a 6-value die          ',
'07:58 PM',
'PenelopeHB delivers a meat to a craft building         ',
'07:58 PM',
'PenelopeHB unlocks the next craft building         ',
'07:58 PM',
'PenelopeHB has fully supplied the wainwright         ',
'07:58 PM',
'PenelopeHB receives 7 vp ( 5vp based on round value / 1vp first to complete this craft building / 1vp unlocking next building )         ',
'07:58 PM',
'PenelopeHB gets ',
'         ',
'07:58 PM',
'PenelopeHB delivers a grape to a craft building         ',
'07:59 PM',
'MandelMarie takes a 1-value die          ',
'08:03 PM',
'MandelMarie receives a pig         ',
'08:03 PM',
'PenelopeHB takes a 1-value die          ',
'08:05 PM',
'PenelopeHB receives a pig         ',
'08:05 PM',
'MandelMarie takes a 2-value die          ',
'09:35 PM',
'MandelMarie plays card 59 as extension         ',
'09:36 PM',
'MandelMarie pays grain         ',
'09:36 PM',
'MandelMarie pays 1 silver         ',
'09:36 PM',
'MandelMarie returns a trade commodity         ',
'09:38 PM',
'MandelMarie plays card 31 as extension         ',
'09:38 PM',
'MandelMarie pays 1 silver         ',
'09:38 PM',
'MandelMarie pays olive         ',
'09:38 PM',
'MandelMarie pays 1 vp          ',
'09:38 PM',
'MandelMarie returns a trade commodity         ',
'09:39 PM',
'MandelMarie receives a pig         ',
'09:39 PM',
'MandelMarie activates helper Farm Servant         ',
'09:39 PM',
'MandelMarie upgrades grape to wine         ',
'09:39 PM',
'MandelMarie activates helper Porter         ',
'09:40 PM',
'MandelMarie takes a grape         ',
'09:40 PM',
'PenelopeHB advances 1 step(s) on the siesta track         ',
'09:42 PM',
'PenelopeHB upgrades grain to food         ',
'09:42 PM',
'MandelMarie upgrades pig to meat         ',
'10:02 PM',
'MandelMarie upgrades pig to meat         ',
'10:02 PM',
'PenelopeHB reveals ',
'         ',
'10:03 PM',
'MandelMarie reveals ',
'         ',
'10:03 PM',
'MandelMarie advances 1 step(s) on the siesta track         ',
'10:03 PM',
'MandelMarie delivers a food to a barrow         ',
'10:05 PM',
'MandelMarie delivers a meat to a barrow         ',
'10:05 PM',
'MandelMarie has fully supplied a market barrow.         ',
'10:05 PM',
'MandelMarie places a marker in the market and gets a trade commodity         ',
'10:05 PM',
'MandelMarie receives 6 vp          ',
'10:05 PM',
'MandelMarie delivers a meat to a barrow         ',
'10:05 PM',
'MandelMarie has fully supplied a market barrow.         ',
'10:05 PM',
'MandelMarie places a marker in the market and gets a trade commodity         ',
'10:05 PM',
'MandelMarie receives 6 vp ( 5vp market barrow value / 1vp booting marker )         ',
'10:05 PM',
'MandelMarie activates a roof         ',
'10:06 PM',
'MandelMarie delivers a wine to a barrow         ',
'10:06 PM',
'MandelMarie activates a roof         ',
'10:06 PM',
'MandelMarie takes a olive         ',
'10:06 PM',
'MandelMarie activates a roof         ',
'10:06 PM',
'MandelMarie takes a grain         ',
'10:06 PM',
'PenelopeHB pays 1 silver         ',
'10:08 PM',
'PenelopeHB delivers a silver to a craft building         ',
'10:08 PM',
'PenelopeHB delivers a pig to a craft building         ',
'10:08 PM',
'PenelopeHB has fully supplied the village store         ',
'10:08 PM',
'PenelopeHB receives 6 vp ( 5vp based on round value / 1vp first to complete this craft building )         ',
'10:08 PM',
'PenelopeHB gets ',
'         ',
'10:08 PM',
'PenelopeHB receives 2 vp          ',
'10:08 PM',
'PenelopeHB delivers a garden good to a barrow         ',
'10:08 PM',
'PenelopeHB delivers a pig to a barrow         ',
'10:08 PM',
'PenelopeHB has fully supplied a market barrow.         ',
'10:08 PM',
'PenelopeHB places a marker in the market and gets a trade commodity         ',
'10:09 PM',
'PenelopeHB receives 8 vp ( 6vp market barrow value / 1vp booting marker / 1vp booting marker )         ',
'10:09 PM',
'6/15/2020',
'MandelMarie buys 3 extra deliveries         ',
'12:37 PM',
'MandelMarie pays 3 silver         ',
'12:37 PM',
'MandelMarie delivers a olive to a barrow         ',
'12:37 PM',
'MandelMarie delivers a grain to a barrow         ',
'12:37 PM',
'MandelMarie delivers a grape to a barrow         ',
'12:38 PM',
'MandelMarie has fully supplied a market barrow.         ',
'12:38 PM',
'MandelMarie places a marker in the market and gets a trade commodity         ',
'12:38 PM',
'MandelMarie receives 5 vp          ',
'12:38 PM',
'MandelMarie returns a trade commodity         ',
'12:40 PM',
'MandelMarie receives 4 silver         ',
'12:40 PM',
'MandelMarie returns a trade commodity         ',
'12:40 PM',
'MandelMarie receives 4 silver         ',
'12:40 PM',
'MandelMarie returns a trade commodity         ',
'12:40 PM',
'MandelMarie receives 4 silver         ',
'12:40 PM',
'PenelopeHB returns a trade commodity         ',
'06:22 PM',
'PenelopeHB plays card 10 as barrow         ',
'06:22 PM',
'PenelopeHB buys 2 extra deliveries         ',
'06:22 PM',
'PenelopeHB pays 2 silver         ',
'06:22 PM',
'PenelopeHB delivers a food to a barrow         ',
'06:22 PM',
'PenelopeHB delivers a garden good to a barrow         ',
'06:22 PM',
'PenelopeHB has fully supplied a market barrow.         ',
'06:22 PM',
'PenelopeHB places a marker in the market and gets a trade commodity         ',
'06:23 PM',
'PenelopeHB receives 2 vp          ',
'06:23 PM',
'PenelopeHB receives 3 vp ( 0vp from siesta track / 3vp from markers in the market )         ',
'06:23 PM',
'MandelMarie receives 3 vp ( 0vp from siesta track / 3vp from markers in the market )         ',
'06:23 PM',
'A new round begins!         ',
'06:23 PM',
'PenelopeHB plays card 2 as barrow         ',
'06:30 PM',
'PenelopeHB returns a trade commodity         ',
'06:30 PM',
'PenelopeHB receives a pig         ',
'06:30 PM',
'PenelopeHB draws 2 cards         ',
'06:30 PM',
'PenelopeHB receives 3 silver         ',
'06:30 PM',
'PenelopeHB fields grow         ',
'06:31 PM',
'PenelopeHB receives pig offspring         ',
'06:31 PM',
'PenelopeHB activates helper Gardener         ',
'06:31 PM',
'MandelMarie plays card 37 as barrow         ',
'06:59 PM',
'MandelMarie draws 5 cards         ',
'07:11 PM',
'MandelMarie gets a trade commodity         ',
'07:11 PM',
'MandelMarie receives 6 silver         ',
'07:11 PM',
'MandelMarie fields grow         ',
'10:04 PM',
'MandelMarie collects no pig offspring         ',
'10:04 PM',
]


name1 = "Pen"
name2 = "Man"
points1 = 0
points2 = 0
players = {}

players[name1] = points1

for line in notes:
    #only use lines that include victory points (vp)
    if line.find("vp")>0 and line.find("receives")>0:
        
        if line[0:3] == name1:
            index = line.find("vp")
            new_points1 = int(line[index-2])
            print(line)
            print(f"{name1} new_points {new_points1}")

            points1 = points1 + new_points1
            players[name1] = points1
            print(players)
            print("\n")
            
        elif line[0:3] == name2:
                
            index = line.find("vp")
            new_points2 = int(line[index-2])
            print(line)
            print(f"{name2} new_points {new_points2}")

            points2 = points2 + new_points2
            players[name2] = points2
            print(players)
            print("\n")

    else:
        pass
    
#this is good but it needs to take into account if someone pays vp and minus them...
# Out:
# PenelopeHB receives 1 vp ( 0vp from siesta track / 1vp from markers in the market )
# Pen new_points 1
# {'Pen': 1}
#
#
# MandelMarie receives 2 vp ( 1vp from siesta track / 1vp from markers in the market )
# Man new_points 2
# {'Pen': 1, 'Man': 2}
#
#
# MandelMarie receives 1 vp
# Man new_points 1
# {'Pen': 1, 'Man': 3}
#
#
# PenelopeHB receives 7 vp ( 6vp market barrow value / 1vp booting marker )
# Pen new_points 7
# {'Pen': 8, 'Man': 3}
#
#
# PenelopeHB receives 2 vp ( 0vp from siesta track / 2vp from markers in the market )
# Pen new_points 2
# {'Pen': 10, 'Man': 3}
#
#
# MandelMarie receives 0 vp ( 0vp from siesta track / 0vp from markers in the market )
# Man new_points 0
# {'Pen': 10, 'Man': 3}
#
#
# MandelMarie receives 2 vp
# Man new_points 2
# {'Pen': 10, 'Man': 5}
#
#
# MandelMarie receives 5 vp ( 3vp based on round value / 1vp first to complete this craft building / 1vp unlocking next building )
# Man new_points 5
# {'Pen': 10, 'Man': 10}
#
#
# PenelopeHB receives 3 vp
# ...
